# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('gabung_all.csv')

# %%
# Menghitung jumlah label dengan masing-masing sentimennya
sentimen_count = data['label'].value_counts()

# Menampilkan hasilnya
print(sentimen_count)

# Membuat pie chart untuk setiap label
fig, ax = plt.subplots()
ax.pie(sentimen_count, labels=sentimen_count.index, autopct='%1.1f%%')
ax.axis('equal')
plt.title('Jumlah Label Data Asli \n(total = 12.520 tweets)')
plt.savefig('hasil F1 Measure Stopword/pie_chart_label_asli.png')
plt.show()
# Out:
# negative    8734
# positive    1940
# neutral     1846
# Name: label, dtype: int64

# %%
data_clus= pd.read_csv('01. Hasil_Stop/Hasil_tweets_data_stop.csv')

# %%
# Menghitung jumlah label dengan masing-masing sentimennya
sentimen_count = data_clus['polarity'].value_counts()

# Menampilkan hasilnya
print(sentimen_count)

# Membuat pie chart
fig, ax = plt.subplots()
ax.pie(sentimen_count, labels=sentimen_count.index, autopct='%1.1f%%')
ax.axis('equal')
plt.title('Jumlah Label Data InSet')
plt.savefig('hasil F1 Measure Stopword/pie_chart_label_cluster.png')
plt.show()
# Out:
# negative    8811
# positive    2962
# neutral      747
# Name: polarity, dtype: int64

# %%
data_clus
# Out:
#                                                     text     label  \
# 0      Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...  negative
# 1      Belum jadi kok sudah mau memindahkan ASN Pak? ...  negative
# 2      Sampai di IKN, asn nya mengeluh...oala disini ...  negative
# 3      Emang ikn jadi kapan? Kayak dia masih menjabat...  negative
# 4      Tdk semudah itu ASN wajib pindah ke IKN tahun ...  negative
# ...                                                  ...       ...
# 12515  Kadang gimana gitu y pak, \nJadi ngerasa bener...  positive
# 12516  DPR secara institusi sudah menyetujui IKN yg t...  positive
# 12517  #2022JokowiSelesai Ikn,Nusantara,Bp \n@jokowi\...  positive
# 12518  Sejarah besar ....\nBalap motor GP Mandalika\n...  positive
# 12519  Bapak, Saya merantau ke Jakarta dr Jateng thn ...  positive
#
#                                       pisah_hashtag&kata  \
# 0      Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...
# 1      Belum jadi kok sudah mau memindahkan ASN Pak? ...
# 2      Sampai di IKN, asn nya mengeluh...oala disini ...
# 3      Emang ikn jadi kapan? Kayak dia masih menjabat...
# 4      Tdk semudah itu ASN wajib pindah ke IKN tahun ...
# ...                                                  ...
# 12515  Kadang gimana gitu y pak, \nJadi ngerasa bener...
# 12516  DPR secara institusi sudah menyetujui IKN yg t...
# 12517  #2022Jokowi Selesai Ikn,Nusantara,Bp \n@jokowi...
# 12518  Sejarah besar ....\nBalap motor GP Mandalika\n...
# 12519  Bapak, Saya merantau ke Jakarta dr Jateng thn ...
#
#                                            text_cleaning  \
# 0      lho dia yg minta ikn kok otorita di bebani ya ...
# 1      belum jadi kok sudah mau memindahkan asn pak y...
# 2      sampai di ikn asn nya mengeluh oala disini bar...
# 3      emang ikn jadi kapan kayak dia masih menjabat ...
# 4      tdk semudah itu asn wajib pindah ke ikn tahun ...
# ...                                                  ...
# 12515  kadang gimana gitu  pak jadi ngerasa bener bui...
# 12516  dpr secara institusi sudah menyetujui ikn yg t...
# 12517  jokowi selesai ikn nusantara bp akan sangat ma...
# 12518  sejarah besar balap motor gp mandalika terbent...
# 12519  bapak saya merantau ke jakarta dr jateng thn  ...
#
#                                         text_normalisasi  \
# 0      lho dia yang minta ibu kota negara kok otorita...
# 1      belum jadi kok sudah mau memindahkan asn pak y...
# 2      sampai di ibu kota negara asn nya mengeluh oal...
# 3      emang ibu kota negara jadi kapan kayak dia mas...
# 4      tidak semudah itu asn wajib pindah ke ibu kota...
# ...                                                  ...
# 12515  kadang bagaimana gitu  pak jadi merasa benar b...
# 12516  dpr secara institusi sudah menyetujui ibu kota...
# 12517  jokowi  selesai ibu kota negara nusantara bapa...
# 12518  sejarah besar balap motor gp mandalika terbent...
# 12519  bapak saya merantau ke jakarta dari jawa tenga...
#
#                                             tweet_tokens  \
# 0      ['lho', 'dia', 'yang', 'minta', 'ibu', 'kota',...
# 1      ['belum', 'jadi', 'kok', 'sudah', 'mau', 'memi...
# 2      ['sampai', 'di', 'ibu', 'kota', 'negara', 'asn...
# 3      ['emang', 'ibu', 'kota', 'negara', 'jadi', 'ka...
# 4      ['tidak', 'semudah', 'itu', 'asn', 'wajib', 'p...
# ...                                                  ...
# 12515  ['kadang', 'bagaimana', 'gitu', 'pak', 'jadi',...
# 12516  ['dpr', 'secara', 'institusi', 'sudah', 'menye...
# 12517  ['jokowi', 'selesai', 'ibu', 'kota', 'negara',...
# 12518  ['sejarah', 'besar', 'balap', 'motor', 'gp', '...
# 12519  ['bapak', 'saya', 'merantau', 'ke', 'jakarta',...
#
#                                         tweet_tokens_WSW  polarity_score  \
# 0      ['lho', 'kota', 'negara', 'otoritas', 'beban',...              -6
# 1      ['memindahkan', 'asn', 'kota', 'negara', 'ment...              -5
# 2      ['kota', 'negara', 'asn', 'mengeluh', 'oalah',...               6
# 3      ['emang', 'kota', 'negara', 'kayak', 'menjabat...              -4
# 4      ['semudah', 'asn', 'wajib', 'pindah', 'kota', ...              -9
# ...                                                  ...             ...
# 12515  ['kadang', 'gitu', 'buih', 'pa', 'adjem', 'lih...               2
# 12516  ['dpr', 'institusi', 'menyetujui', 'kota', 'ne...               8
# 12517  ['jokowi', 'selesai', 'kota', 'negara', 'nusan...              -7
# 12518  ['sejarah', 'balap', 'motor', 'gp', 'mandalika...              -1
# 12519  ['merantau', 'jakarta', 'jawa', 'susah', 'cr',...               7
#
#        polarity                                     positive_words  \
# 0      negative                                                 []
# 1      negative                               [('memindahkan', 1)]
# 2      positive  [('kerja', 2), ('berdarah', 4), ('dengar', 2),...
# 3      negative                                                 []
# 4      negative                     [('pindah', 1), ('banget', 1)]
# ...         ...                                                ...
# 12515  positive  [('kadang', 3), ('lihat', 3), ('umat', 3), ('i...
# 12516  positive  [('presiden', 3), ('sosial', 4), ('setuju', 4)...
# 12517  negative  [('selesai', 2), ('harap', 3), ('hati', 2), ('...
# 12518  negative                                                 []
# 12519  positive  [('pekerjaan', 3), ('sesuai', 3), ('pekerjaan'...
#
#                                           negative_words
# 0                          [('kota', -1), ('beban', -5)]
# 1                    [('memindahkan', -5), ('kota', -1)]
# 2      [('kota', -1), ('kena', -3), ('suara', -1), ('...
# 3                          [('kota', -1), ('kayak', -3)]
# 4      [('wajib', -2), ('pindah', -3), ('kota', -1), ...
# ...                                                  ...
# 12515             [('pa', -5), ('kota', -1), ('pa', -5)]
# 12516  [('kota', -1), ('melaksanakan', -3), ('setuju'...
# 12517  [('selesai', -4), ('kota', -1), ('harap', -3),...
# 12518                                     [('kota', -1)]
# 12519        [('susah', -3), ('kota', -1), ('sila', -4)]
#
# [12520 rows x 11 columns]

# %%
label_dict = {'neutral': 0, 'positive': 1, 'negative': -1}
data['label'] = data['label'].apply(lambda x: label_dict[x])

# Menampilkan DataFrame setelah pengubahan label
print(data)
# Out:
#                                                     text  label
# 0      Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...     -1
# 1      Belum jadi kok sudah mau memindahkan ASN Pak? ...     -1
# 2      Sampai di IKN, asn nya mengeluh...oala disini ...     -1
# 3      Emang ikn jadi kapan? Kayak dia masih menjabat...     -1
# 4      Tdk semudah itu ASN wajib pindah ke IKN tahun ...     -1
# ...                                                  ...    ...
# 12515  Kadang gimana gitu y pak, \nJadi ngerasa bener...      1
# 12516  DPR secara institusi sudah menyetujui IKN yg t...      1
# 12517  #2022JokowiSelesai Ikn,Nusantara,Bp \n@jokowi\...      1
# 12518  Sejarah besar ....\nBalap motor GP Mandalika\n...      1
# 12519  Bapak, Saya merantau ke Jakarta dr Jateng thn ...      1
#
# [12520 rows x 2 columns]

# %%
data_clus
# Out:
#                                                     text     label  \
# 0      Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...  negative
# 1      Belum jadi kok sudah mau memindahkan ASN Pak? ...  negative
# 2      Sampai di IKN, asn nya mengeluh...oala disini ...  negative
# 3      Emang ikn jadi kapan? Kayak dia masih menjabat...  negative
# 4      Tdk semudah itu ASN wajib pindah ke IKN tahun ...  negative
# ...                                                  ...       ...
# 12515  Kadang gimana gitu y pak, \nJadi ngerasa bener...  positive
# 12516  DPR secara institusi sudah menyetujui IKN yg t...  positive
# 12517  #2022JokowiSelesai Ikn,Nusantara,Bp \n@jokowi\...  positive
# 12518  Sejarah besar ....\nBalap motor GP Mandalika\n...  positive
# 12519  Bapak, Saya merantau ke Jakarta dr Jateng thn ...  positive
#
#                                       pisah_hashtag&kata  \
# 0      Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...
# 1      Belum jadi kok sudah mau memindahkan ASN Pak? ...
# 2      Sampai di IKN, asn nya mengeluh...oala disini ...
# 3      Emang ikn jadi kapan? Kayak dia masih menjabat...
# 4      Tdk semudah itu ASN wajib pindah ke IKN tahun ...
# ...                                                  ...
# 12515  Kadang gimana gitu y pak, \nJadi ngerasa bener...
# 12516  DPR secara institusi sudah menyetujui IKN yg t...
# 12517  #2022Jokowi Selesai Ikn,Nusantara,Bp \n@jokowi...
# 12518  Sejarah besar ....\nBalap motor GP Mandalika\n...
# 12519  Bapak, Saya merantau ke Jakarta dr Jateng thn ...
#
#                                            text_cleaning  \
# 0      lho dia yg minta ikn kok otorita di bebani ya ...
# 1      belum jadi kok sudah mau memindahkan asn pak y...
# 2      sampai di ikn asn nya mengeluh oala disini bar...
# 3      emang ikn jadi kapan kayak dia masih menjabat ...
# 4      tdk semudah itu asn wajib pindah ke ikn tahun ...
# ...                                                  ...
# 12515  kadang gimana gitu  pak jadi ngerasa bener bui...
# 12516  dpr secara institusi sudah menyetujui ikn yg t...
# 12517  jokowi selesai ikn nusantara bp akan sangat ma...
# 12518  sejarah besar balap motor gp mandalika terbent...
# 12519  bapak saya merantau ke jakarta dr jateng thn  ...
#
#                                         text_normalisasi  \
# 0      lho dia yang minta ibu kota negara kok otorita...
# 1      belum jadi kok sudah mau memindahkan asn pak y...
# 2      sampai di ibu kota negara asn nya mengeluh oal...
# 3      emang ibu kota negara jadi kapan kayak dia mas...
# 4      tidak semudah itu asn wajib pindah ke ibu kota...
# ...                                                  ...
# 12515  kadang bagaimana gitu  pak jadi merasa benar b...
# 12516  dpr secara institusi sudah menyetujui ibu kota...
# 12517  jokowi  selesai ibu kota negara nusantara bapa...
# 12518  sejarah besar balap motor gp mandalika terbent...
# 12519  bapak saya merantau ke jakarta dari jawa tenga...
#
#                                             tweet_tokens  \
# 0      ['lho', 'dia', 'yang', 'minta', 'ibu', 'kota',...
# 1      ['belum', 'jadi', 'kok', 'sudah', 'mau', 'memi...
# 2      ['sampai', 'di', 'ibu', 'kota', 'negara', 'asn...
# 3      ['emang', 'ibu', 'kota', 'negara', 'jadi', 'ka...
# 4      ['tidak', 'semudah', 'itu', 'asn', 'wajib', 'p...
# ...                                                  ...
# 12515  ['kadang', 'bagaimana', 'gitu', 'pak', 'jadi',...
# 12516  ['dpr', 'secara', 'institusi', 'sudah', 'menye...
# 12517  ['jokowi', 'selesai', 'ibu', 'kota', 'negara',...
# 12518  ['sejarah', 'besar', 'balap', 'motor', 'gp', '...
# 12519  ['bapak', 'saya', 'merantau', 'ke', 'jakarta',...
#
#                                         tweet_tokens_WSW  polarity_score  \
# 0      ['lho', 'kota', 'negara', 'otoritas', 'beban',...              -6
# 1      ['memindahkan', 'asn', 'kota', 'negara', 'ment...              -5
# 2      ['kota', 'negara', 'asn', 'mengeluh', 'oalah',...               6
# 3      ['emang', 'kota', 'negara', 'kayak', 'menjabat...              -4
# 4      ['semudah', 'asn', 'wajib', 'pindah', 'kota', ...              -9
# ...                                                  ...             ...
# 12515  ['kadang', 'gitu', 'buih', 'pa', 'adjem', 'lih...               2
# 12516  ['dpr', 'institusi', 'menyetujui', 'kota', 'ne...               8
# 12517  ['jokowi', 'selesai', 'kota', 'negara', 'nusan...              -7
# 12518  ['sejarah', 'balap', 'motor', 'gp', 'mandalika...              -1
# 12519  ['merantau', 'jakarta', 'jawa', 'susah', 'cr',...               7
#
#        polarity                                     positive_words  \
# 0      negative                                                 []
# 1      negative                               [('memindahkan', 1)]
# 2      positive  [('kerja', 2), ('berdarah', 4), ('dengar', 2),...
# 3      negative                                                 []
# 4      negative                     [('pindah', 1), ('banget', 1)]
# ...         ...                                                ...
# 12515  positive  [('kadang', 3), ('lihat', 3), ('umat', 3), ('i...
# 12516  positive  [('presiden', 3), ('sosial', 4), ('setuju', 4)...
# 12517  negative  [('selesai', 2), ('harap', 3), ('hati', 2), ('...
# 12518  negative                                                 []
# 12519  positive  [('pekerjaan', 3), ('sesuai', 3), ('pekerjaan'...
#
#                                           negative_words
# 0                          [('kota', -1), ('beban', -5)]
# 1                    [('memindahkan', -5), ('kota', -1)]
# 2      [('kota', -1), ('kena', -3), ('suara', -1), ('...
# 3                          [('kota', -1), ('kayak', -3)]
# 4      [('wajib', -2), ('pindah', -3), ('kota', -1), ...
# ...                                                  ...
# 12515             [('pa', -5), ('kota', -1), ('pa', -5)]
# 12516  [('kota', -1), ('melaksanakan', -3), ('setuju'...
# 12517  [('selesai', -4), ('kota', -1), ('harap', -3),...
# 12518                                     [('kota', -1)]
# 12519        [('susah', -3), ('kota', -1), ('sila', -4)]
#
# [12520 rows x 11 columns]

# %%
label_dict = {'neutral': 0, 'positive': 1, 'negative': -1}
data_clus['polarity'] = data_clus['polarity'].apply(lambda x: label_dict[x])

# Menampilkan DataFrame setelah pengubahan label
print(data_clus)
# Out:
#                                                     text     label  \
# 0      Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...  negative
# 1      Belum jadi kok sudah mau memindahkan ASN Pak? ...  negative
# 2      Sampai di IKN, asn nya mengeluh...oala disini ...  negative
# 3      Emang ikn jadi kapan? Kayak dia masih menjabat...  negative
# 4      Tdk semudah itu ASN wajib pindah ke IKN tahun ...  negative
# ...                                                  ...       ...
# 12515  Kadang gimana gitu y pak, \nJadi ngerasa bener...  positive
# 12516  DPR secara institusi sudah menyetujui IKN yg t...  positive
# 12517  #2022JokowiSelesai Ikn,Nusantara,Bp \n@jokowi\...  positive
# 12518  Sejarah besar ....\nBalap motor GP Mandalika\n...  positive
# 12519  Bapak, Saya merantau ke Jakarta dr Jateng thn ...  positive
#
#                                       pisah_hashtag&kata  \
# 0      Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...
# 1      Belum jadi kok sudah mau memindahkan ASN Pak? ...
# 2      Sampai di IKN, asn nya mengeluh...oala disini ...
# 3      Emang ikn jadi kapan? Kayak dia masih menjabat...
# 4      Tdk semudah itu ASN wajib pindah ke IKN tahun ...
# ...                                                  ...
# 12515  Kadang gimana gitu y pak, \nJadi ngerasa bener...
# 12516  DPR secara institusi sudah menyetujui IKN yg t...
# 12517  #2022Jokowi Selesai Ikn,Nusantara,Bp \n@jokowi...
# 12518  Sejarah besar ....\nBalap motor GP Mandalika\n...
# 12519  Bapak, Saya merantau ke Jakarta dr Jateng thn ...
#
#                                            text_cleaning  \
# 0      lho dia yg minta ikn kok otorita di bebani ya ...
# 1      belum jadi kok sudah mau memindahkan asn pak y...
# 2      sampai di ikn asn nya mengeluh oala disini bar...
# 3      emang ikn jadi kapan kayak dia masih menjabat ...
# 4      tdk semudah itu asn wajib pindah ke ikn tahun ...
# ...                                                  ...
# 12515  kadang gimana gitu  pak jadi ngerasa bener bui...
# 12516  dpr secara institusi sudah menyetujui ikn yg t...
# 12517  jokowi selesai ikn nusantara bp akan sangat ma...
# 12518  sejarah besar balap motor gp mandalika terbent...
# 12519  bapak saya merantau ke jakarta dr jateng thn  ...
#
#                                         text_normalisasi  \
# 0      lho dia yang minta ibu kota negara kok otorita...
# 1      belum jadi kok sudah mau memindahkan asn pak y...
# 2      sampai di ibu kota negara asn nya mengeluh oal...
# 3      emang ibu kota negara jadi kapan kayak dia mas...
# 4      tidak semudah itu asn wajib pindah ke ibu kota...
# ...                                                  ...
# 12515  kadang bagaimana gitu  pak jadi merasa benar b...
# 12516  dpr secara institusi sudah menyetujui ibu kota...
# 12517  jokowi  selesai ibu kota negara nusantara bapa...
# 12518  sejarah besar balap motor gp mandalika terbent...
# 12519  bapak saya merantau ke jakarta dari jawa tenga...
#
#                                             tweet_tokens  \
# 0      ['lho', 'dia', 'yang', 'minta', 'ibu', 'kota',...
# 1      ['belum', 'jadi', 'kok', 'sudah', 'mau', 'memi...
# 2      ['sampai', 'di', 'ibu', 'kota', 'negara', 'asn...
# 3      ['emang', 'ibu', 'kota', 'negara', 'jadi', 'ka...
# 4      ['tidak', 'semudah', 'itu', 'asn', 'wajib', 'p...
# ...                                                  ...
# 12515  ['kadang', 'bagaimana', 'gitu', 'pak', 'jadi',...
# 12516  ['dpr', 'secara', 'institusi', 'sudah', 'menye...
# 12517  ['jokowi', 'selesai', 'ibu', 'kota', 'negara',...
# 12518  ['sejarah', 'besar', 'balap', 'motor', 'gp', '...
# 12519  ['bapak', 'saya', 'merantau', 'ke', 'jakarta',...
#
#                                         tweet_tokens_WSW  polarity_score  \
# 0      ['lho', 'kota', 'negara', 'otoritas', 'beban',...              -6
# 1      ['memindahkan', 'asn', 'kota', 'negara', 'ment...              -5
# 2      ['kota', 'negara', 'asn', 'mengeluh', 'oalah',...               6
# 3      ['emang', 'kota', 'negara', 'kayak', 'menjabat...              -4
# 4      ['semudah', 'asn', 'wajib', 'pindah', 'kota', ...              -9
# ...                                                  ...             ...
# 12515  ['kadang', 'gitu', 'buih', 'pa', 'adjem', 'lih...               2
# 12516  ['dpr', 'institusi', 'menyetujui', 'kota', 'ne...               8
# 12517  ['jokowi', 'selesai', 'kota', 'negara', 'nusan...              -7
# 12518  ['sejarah', 'balap', 'motor', 'gp', 'mandalika...              -1
# 12519  ['merantau', 'jakarta', 'jawa', 'susah', 'cr',...               7
#
#        polarity                                     positive_words  \
# 0            -1                                                 []
# 1            -1                               [('memindahkan', 1)]
# 2             1  [('kerja', 2), ('berdarah', 4), ('dengar', 2),...
# 3            -1                                                 []
# 4            -1                     [('pindah', 1), ('banget', 1)]
# ...         ...                                                ...
# 12515         1  [('kadang', 3), ('lihat', 3), ('umat', 3), ('i...
# 12516         1  [('presiden', 3), ('sosial', 4), ('setuju', 4)...
# 12517        -1  [('selesai', 2), ('harap', 3), ('hati', 2), ('...
# 12518        -1                                                 []
# 12519         1  [('pekerjaan', 3), ('sesuai', 3), ('pekerjaan'...
#
#                                           negative_words
# 0                          [('kota', -1), ('beban', -5)]
# 1                    [('memindahkan', -5), ('kota', -1)]
# 2      [('kota', -1), ('kena', -3), ('suara', -1), ('...
# 3                          [('kota', -1), ('kayak', -3)]
# 4      [('wajib', -2), ('pindah', -3), ('kota', -1), ...
# ...                                                  ...
# 12515             [('pa', -5), ('kota', -1), ('pa', -5)]
# 12516  [('kota', -1), ('melaksanakan', -3), ('setuju'...
# 12517  [('selesai', -4), ('kota', -1), ('harap', -3),...
# 12518                                     [('kota', -1)]
# 12519        [('susah', -3), ('kota', -1), ('sila', -4)]
#
# [12520 rows x 11 columns]

# %%
y_true = data['label']

# %%
y_pred = data_clus['polarity']

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score

# Menghitung akurasi
accuracy = accuracy_score(y_true, y_pred)

# Menghitung recall
# Menghitung recall dengan rata-rata 'macro'
recall = recall_score(y_true, y_pred, average='macro')

# Menghitung presisi dengan rata-rata 'macro'
precision = precision_score(y_true, y_pred, average='macro')

# Menghitung F1 score
f1 = f1_score(y_true, y_pred, average = 'macro')

accuracy_percent = round(accuracy * 100, 2)
print("Accuracy (%):", accuracy_percent)

recall_percent = format(recall * 100, ".2f")
print("Recall (%):", recall_percent)

precision_score = format(precision * 100, ".2f")
print("Precision score (%):", precision_score)

f1_percent = format(f1 * 100, ".2f")
print("F1 score (%):", f1_percent)
# Out:
# Accuracy (%): 58.69
# Recall (%): 40.43
# Precision score (%): 38.11
# F1 score (%): 38.18

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score

# Menghitung akurasi
accuracy = accuracy_score(y_true, y_pred)

# Menghitung recall
# Menghitung recall dengan rata-rata 'macro'
recall = recall_score(y_true, y_pred, average='weighted')

# Menghitung presisi dengan rata-rata 'macro'
precision = precision_score(y_true, y_pred, average='weighted')

# Menghitung F1 score
f1 = f1_score(y_true, y_pred, average = 'weighted')

accuracy_percent = round(accuracy * 100, 2)
print("Accuracy (%):", accuracy_percent)

recall_percent = format(recall * 100, ".2f")
print("Recall (%):", recall_percent)

precision_score = format(precision * 100, ".2f")
print("Precision score (%):", precision_score)

f1_percent = format(f1 * 100, ".2f")
print("F1 score (%):", f1_percent)
# Out:
# Accuracy (%): 58.69
# Recall (%): 58.69
# Precision score (%): 57.20
# F1 score (%): 57.45
