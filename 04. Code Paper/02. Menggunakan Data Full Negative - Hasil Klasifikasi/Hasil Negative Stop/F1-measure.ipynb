# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('negative.csv')

# %%
# Menghitung jumlah label dengan masing-masing sentimennya
sentimen_count = data['label'].value_counts()

# Menampilkan hasilnya
print(sentimen_count)

# Membuat pie chart untuk setiap label
fig, ax = plt.subplots()
ax.pie(sentimen_count, labels=sentimen_count.index, autopct='%1.1f%%')
ax.axis('equal')
plt.title('Jumlah Label Data Asli \n(total = 8.734 tweets)')
plt.savefig('hasil1/pie_chart_label_asli.png')
plt.show()
# Out:
# negative    8734
# Name: label, dtype: int64

# %%
data_clus= pd.read_csv('hasil2stem/Hasil_tweets_negative.csv')

# %%
# Menghitung jumlah label dengan masing-masing sentimennya
sentimen_count = data_clus['polarity'].value_counts()

# Menampilkan hasilnya
print(sentimen_count)

# Membuat pie chart
fig, ax = plt.subplots()
ax.pie(sentimen_count, labels=sentimen_count.index, autopct='%1.1f%%')
ax.axis('equal')
plt.title('Jumlah Label Data InSet')
plt.savefig('hasil1/pie_chart_label_cluster.png')
plt.show()
# Out:
# negative    6428
# positive    1788
# neutral      518
# Name: polarity, dtype: int64

# %%
data_clus
# Out:
#                                                    text     label  \
# 0     Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...  negative
# 1     Belum jadi kok sudah mau memindahkan ASN Pak? ...  negative
# 2     Sampai di IKN, asn nya mengeluh...oala disini ...  negative
# 3     Emang ikn jadi kapan? Kayak dia masih menjabat...  negative
# 4     Tdk semudah itu ASN wajib pindah ke IKN tahun ...  negative
# ...                                                 ...       ...
# 8729  Program IKN pertama: Membangun kerjasama denga...  negative
# 8730  Dirangkul demi menyejahterakan anak-cucu para ...  negative
# 8731  Rapim TNI-POLRI seharusnya banyak hal lain yan...  negative
# 8732  Harusnya para gub itu bukan bawa tanah tp bawa...  negative
# 8733  Siapa bilang kemping di IKN tak ada hasilnya, ...  negative
#
#                                      pisah_hashtag&kata  \
# 0     Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...
# 1     Belum jadi kok sudah mau memindahkan ASN Pak? ...
# 2     Sampai di IKN, asn nya mengeluh...oala disini ...
# 3     Emang ikn jadi kapan? Kayak dia masih menjabat...
# 4     Tdk semudah itu ASN wajib pindah ke IKN tahun ...
# ...                                                 ...
# 8729  Program IKN pertama: Membangun kerjasama denga...
# 8730  Dirangkul demi menyejahterakan anak-cucu para ...
# 8731  Rapim TNI-POLRI seharusnya banyak hal lain yan...
# 8732  Harusnya para gub itu bukan bawa tanah tp bawa...
# 8733  Siapa bilang kemping di IKN tak ada hasilnya, ...
#
#                                           text_cleaning  \
# 0     lho dia yg minta ikn kok otorita di bebani ya ...
# 1     belum jadi kok sudah mau memindahkan asn pak y...
# 2     sampai di ikn asn nya mengeluh oala disini bar...
# 3     emang ikn jadi kapan kayak dia masih menjabat ...
# 4     tdk semudah itu asn wajib pindah ke ikn tahun ...
# ...                                                 ...
# 8729  program ikn pertama membangun kerjasama dengan...
# 8730  dirangkul demi menyejahterakan anak-cucu para ...
# 8731  rapim tni-polri seharusnya banyak hal lain yan...
# 8732  harusnya para gub itu bukan bawa tanah tp bawa...
# 8733  siapa bilang kemping di ikn tak ada hasilnya l...
#
#                                        text_normalisasi  \
# 0     lho dia yang minta ibu kota negara kok otorita...
# 1     belum jadi kok sudah mau memindahkan asn pak y...
# 2     sampai di ibu kota negara asn nya mengeluh oal...
# 3     emang ibu kota negara jadi kapan kayak dia mas...
# 4     tidak semudah itu asn wajib pindah ke ibu kota...
# ...                                                 ...
# 8729  program ibu kota negara pertama membangun kerj...
# 8730  dirangkul demi menyejahterakan anak-cucu para ...
# 8731  rapim tentara nasional indonesia-polri seharus...
# 8732  harusnya para gubernur itu bukan bawa tanah ta...
# 8733  siapa bilang kemping di ibu kota negara tidak ...
#
#                                            tweet_tokens  \
# 0     ['lho', 'dia', 'yang', 'minta', 'ibu', 'kota',...
# 1     ['belum', 'jadi', 'kok', 'sudah', 'mau', 'memi...
# 2     ['sampai', 'di', 'ibu', 'kota', 'negara', 'asn...
# 3     ['emang', 'ibu', 'kota', 'negara', 'jadi', 'ka...
# 4     ['tidak', 'semudah', 'itu', 'asn', 'wajib', 'p...
# ...                                                 ...
# 8729  ['program', 'ibu', 'kota', 'negara', 'pertama'...
# 8730  ['dirangkul', 'demi', 'menyejahterakan', 'anak...
# 8731  ['rapim', 'tentara', 'nasional', 'indonesia-po...
# 8732  ['harusnya', 'para', 'gubernur', 'itu', 'bukan...
# 8733  ['siapa', 'bilang', 'kemping', 'di', 'ibu', 'k...
#
#                                        tweet_tokens_WSW  polarity_score  \
# 0     ['lho', 'kota', 'negara', 'otoritas', 'beban',...              -6
# 1     ['memindahkan', 'asn', 'kota', 'negara', 'ment...              -5
# 2     ['kota', 'negara', 'asn', 'mengeluh', 'oalah',...               6
# 3     ['emang', 'kota', 'negara', 'kayak', 'menjabat...              -4
# 4     ['semudah', 'asn', 'wajib', 'pindah', 'kota', ...              -9
# ...                                                 ...             ...
# 8729  ['program', 'kota', 'negara', 'membangun', 'ke...               0
# 8730  ['dirangkul', 'menyejahterakan', 'anak-cucu', ...               3
# 8731  ['rapim', 'tentara', 'nasional', 'indonesia-po...              -3
# 8732  ['gubernur', 'bawa', 'tanah', 'bawa', 'kas', '...              -5
# 8733  ['kemping', 'kota', 'negara', 'hasilnya', 'pen...              -2
#
#       polarity                                     positive_words  \
# 0     negative                                                 []
# 1     negative                               [('memindahkan', 1)]
# 2     positive  [('kerja', 2), ('berdarah', 4), ('dengar', 2),...
# 3     negative                                                 []
# 4     negative                     [('pindah', 1), ('banget', 1)]
# ...        ...                                                ...
# 8729   neutral                                     [('kerja', 2)]
# 8730  positive                                      [('dana', 4)]
# 8731  negative                                                 []
# 8732  negative                         [('bawa', 1), ('bawa', 1)]
# 8733  negative                                    [('goreng', 1)]
#
#                                          negative_words
# 0                         [('kota', -1), ('beban', -5)]
# 1                   [('memindahkan', -5), ('kota', -1)]
# 2     [('kota', -1), ('kena', -3), ('suara', -1), ('...
# 3                         [('kota', -1), ('kayak', -3)]
# 4     [('wajib', -2), ('pindah', -3), ('kota', -1), ...
# ...                                                 ...
# 8729                       [('kota', -1), ('kota', -1)]
# 8730                                     [('kota', -1)]
# 8731         [('kota', -1), ('kota', -1), ('kota', -1)]
# 8732         [('bawa', -3), ('bawa', -3), ('kota', -1)]
# 8733                     [('kota', -1), ('goreng', -2)]
#
# [8734 rows x 11 columns]

# %%
label_dict = {'neutral': 0, 'positive': 1, 'negative': -1}
data['label'] = data['label'].apply(lambda x: label_dict[x])

# Menampilkan DataFrame setelah pengubahan label
print(data)
# Out:
#                                                    text  label
# 0     Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...     -1
# 1     Belum jadi kok sudah mau memindahkan ASN Pak? ...     -1
# 2     Sampai di IKN, asn nya mengeluh...oala disini ...     -1
# 3     Emang ikn jadi kapan? Kayak dia masih menjabat...     -1
# 4     Tdk semudah itu ASN wajib pindah ke IKN tahun ...     -1
# ...                                                 ...    ...
# 8729  Program IKN pertama: Membangun kerjasama denga...     -1
# 8730  Dirangkul demi menyejahterakan anak-cucu para ...     -1
# 8731  Rapim TNI-POLRI seharusnya banyak hal lain yan...     -1
# 8732  Harusnya para gub itu bukan bawa tanah tp bawa...     -1
# 8733  Siapa bilang kemping di IKN tak ada hasilnya, ...     -1
#
# [8734 rows x 2 columns]

# %%
data_clus
# Out:
#                                                    text     label  \
# 0     Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...  negative
# 1     Belum jadi kok sudah mau memindahkan ASN Pak? ...  negative
# 2     Sampai di IKN, asn nya mengeluh...oala disini ...  negative
# 3     Emang ikn jadi kapan? Kayak dia masih menjabat...  negative
# 4     Tdk semudah itu ASN wajib pindah ke IKN tahun ...  negative
# ...                                                 ...       ...
# 8729  Program IKN pertama: Membangun kerjasama denga...  negative
# 8730  Dirangkul demi menyejahterakan anak-cucu para ...  negative
# 8731  Rapim TNI-POLRI seharusnya banyak hal lain yan...  negative
# 8732  Harusnya para gub itu bukan bawa tanah tp bawa...  negative
# 8733  Siapa bilang kemping di IKN tak ada hasilnya, ...  negative
#
#                                      pisah_hashtag&kata  \
# 0     Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...
# 1     Belum jadi kok sudah mau memindahkan ASN Pak? ...
# 2     Sampai di IKN, asn nya mengeluh...oala disini ...
# 3     Emang ikn jadi kapan? Kayak dia masih menjabat...
# 4     Tdk semudah itu ASN wajib pindah ke IKN tahun ...
# ...                                                 ...
# 8729  Program IKN pertama: Membangun kerjasama denga...
# 8730  Dirangkul demi menyejahterakan anak-cucu para ...
# 8731  Rapim TNI-POLRI seharusnya banyak hal lain yan...
# 8732  Harusnya para gub itu bukan bawa tanah tp bawa...
# 8733  Siapa bilang kemping di IKN tak ada hasilnya, ...
#
#                                           text_cleaning  \
# 0     lho dia yg minta ikn kok otorita di bebani ya ...
# 1     belum jadi kok sudah mau memindahkan asn pak y...
# 2     sampai di ikn asn nya mengeluh oala disini bar...
# 3     emang ikn jadi kapan kayak dia masih menjabat ...
# 4     tdk semudah itu asn wajib pindah ke ikn tahun ...
# ...                                                 ...
# 8729  program ikn pertama membangun kerjasama dengan...
# 8730  dirangkul demi menyejahterakan anak-cucu para ...
# 8731  rapim tni-polri seharusnya banyak hal lain yan...
# 8732  harusnya para gub itu bukan bawa tanah tp bawa...
# 8733  siapa bilang kemping di ikn tak ada hasilnya l...
#
#                                        text_normalisasi  \
# 0     lho dia yang minta ibu kota negara kok otorita...
# 1     belum jadi kok sudah mau memindahkan asn pak y...
# 2     sampai di ibu kota negara asn nya mengeluh oal...
# 3     emang ibu kota negara jadi kapan kayak dia mas...
# 4     tidak semudah itu asn wajib pindah ke ibu kota...
# ...                                                 ...
# 8729  program ibu kota negara pertama membangun kerj...
# 8730  dirangkul demi menyejahterakan anak-cucu para ...
# 8731  rapim tentara nasional indonesia-polri seharus...
# 8732  harusnya para gubernur itu bukan bawa tanah ta...
# 8733  siapa bilang kemping di ibu kota negara tidak ...
#
#                                            tweet_tokens  \
# 0     ['lho', 'dia', 'yang', 'minta', 'ibu', 'kota',...
# 1     ['belum', 'jadi', 'kok', 'sudah', 'mau', 'memi...
# 2     ['sampai', 'di', 'ibu', 'kota', 'negara', 'asn...
# 3     ['emang', 'ibu', 'kota', 'negara', 'jadi', 'ka...
# 4     ['tidak', 'semudah', 'itu', 'asn', 'wajib', 'p...
# ...                                                 ...
# 8729  ['program', 'ibu', 'kota', 'negara', 'pertama'...
# 8730  ['dirangkul', 'demi', 'menyejahterakan', 'anak...
# 8731  ['rapim', 'tentara', 'nasional', 'indonesia-po...
# 8732  ['harusnya', 'para', 'gubernur', 'itu', 'bukan...
# 8733  ['siapa', 'bilang', 'kemping', 'di', 'ibu', 'k...
#
#                                        tweet_tokens_WSW  polarity_score  \
# 0     ['lho', 'kota', 'negara', 'otoritas', 'beban',...              -6
# 1     ['memindahkan', 'asn', 'kota', 'negara', 'ment...              -5
# 2     ['kota', 'negara', 'asn', 'mengeluh', 'oalah',...               6
# 3     ['emang', 'kota', 'negara', 'kayak', 'menjabat...              -4
# 4     ['semudah', 'asn', 'wajib', 'pindah', 'kota', ...              -9
# ...                                                 ...             ...
# 8729  ['program', 'kota', 'negara', 'membangun', 'ke...               0
# 8730  ['dirangkul', 'menyejahterakan', 'anak-cucu', ...               3
# 8731  ['rapim', 'tentara', 'nasional', 'indonesia-po...              -3
# 8732  ['gubernur', 'bawa', 'tanah', 'bawa', 'kas', '...              -5
# 8733  ['kemping', 'kota', 'negara', 'hasilnya', 'pen...              -2
#
#       polarity                                     positive_words  \
# 0     negative                                                 []
# 1     negative                               [('memindahkan', 1)]
# 2     positive  [('kerja', 2), ('berdarah', 4), ('dengar', 2),...
# 3     negative                                                 []
# 4     negative                     [('pindah', 1), ('banget', 1)]
# ...        ...                                                ...
# 8729   neutral                                     [('kerja', 2)]
# 8730  positive                                      [('dana', 4)]
# 8731  negative                                                 []
# 8732  negative                         [('bawa', 1), ('bawa', 1)]
# 8733  negative                                    [('goreng', 1)]
#
#                                          negative_words
# 0                         [('kota', -1), ('beban', -5)]
# 1                   [('memindahkan', -5), ('kota', -1)]
# 2     [('kota', -1), ('kena', -3), ('suara', -1), ('...
# 3                         [('kota', -1), ('kayak', -3)]
# 4     [('wajib', -2), ('pindah', -3), ('kota', -1), ...
# ...                                                 ...
# 8729                       [('kota', -1), ('kota', -1)]
# 8730                                     [('kota', -1)]
# 8731         [('kota', -1), ('kota', -1), ('kota', -1)]
# 8732         [('bawa', -3), ('bawa', -3), ('kota', -1)]
# 8733                     [('kota', -1), ('goreng', -2)]
#
# [8734 rows x 11 columns]

# %%
label_dict = {'neutral': 0, 'positive': 1, 'negative': -1}
data_clus['polarity'] = data_clus['polarity'].apply(lambda x: label_dict[x])

# Menampilkan DataFrame setelah pengubahan label
print(data_clus)
# Out:
#                                                    text     label  \
# 0     Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...  negative
# 1     Belum jadi kok sudah mau memindahkan ASN Pak? ...  negative
# 2     Sampai di IKN, asn nya mengeluh...oala disini ...  negative
# 3     Emang ikn jadi kapan? Kayak dia masih menjabat...  negative
# 4     Tdk semudah itu ASN wajib pindah ke IKN tahun ...  negative
# ...                                                 ...       ...
# 8729  Program IKN pertama: Membangun kerjasama denga...  negative
# 8730  Dirangkul demi menyejahterakan anak-cucu para ...  negative
# 8731  Rapim TNI-POLRI seharusnya banyak hal lain yan...  negative
# 8732  Harusnya para gub itu bukan bawa tanah tp bawa...  negative
# 8733  Siapa bilang kemping di IKN tak ada hasilnya, ...  negative
#
#                                      pisah_hashtag&kata  \
# 0     Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Beb...
# 1     Belum jadi kok sudah mau memindahkan ASN Pak? ...
# 2     Sampai di IKN, asn nya mengeluh...oala disini ...
# 3     Emang ikn jadi kapan? Kayak dia masih menjabat...
# 4     Tdk semudah itu ASN wajib pindah ke IKN tahun ...
# ...                                                 ...
# 8729  Program IKN pertama: Membangun kerjasama denga...
# 8730  Dirangkul demi menyejahterakan anak-cucu para ...
# 8731  Rapim TNI-POLRI seharusnya banyak hal lain yan...
# 8732  Harusnya para gub itu bukan bawa tanah tp bawa...
# 8733  Siapa bilang kemping di IKN tak ada hasilnya, ...
#
#                                           text_cleaning  \
# 0     lho dia yg minta ikn kok otorita di bebani ya ...
# 1     belum jadi kok sudah mau memindahkan asn pak y...
# 2     sampai di ikn asn nya mengeluh oala disini bar...
# 3     emang ikn jadi kapan kayak dia masih menjabat ...
# 4     tdk semudah itu asn wajib pindah ke ikn tahun ...
# ...                                                 ...
# 8729  program ikn pertama membangun kerjasama dengan...
# 8730  dirangkul demi menyejahterakan anak-cucu para ...
# 8731  rapim tni-polri seharusnya banyak hal lain yan...
# 8732  harusnya para gub itu bukan bawa tanah tp bawa...
# 8733  siapa bilang kemping di ikn tak ada hasilnya l...
#
#                                        text_normalisasi  \
# 0     lho dia yang minta ibu kota negara kok otorita...
# 1     belum jadi kok sudah mau memindahkan asn pak y...
# 2     sampai di ibu kota negara asn nya mengeluh oal...
# 3     emang ibu kota negara jadi kapan kayak dia mas...
# 4     tidak semudah itu asn wajib pindah ke ibu kota...
# ...                                                 ...
# 8729  program ibu kota negara pertama membangun kerj...
# 8730  dirangkul demi menyejahterakan anak-cucu para ...
# 8731  rapim tentara nasional indonesia-polri seharus...
# 8732  harusnya para gubernur itu bukan bawa tanah ta...
# 8733  siapa bilang kemping di ibu kota negara tidak ...
#
#                                            tweet_tokens  \
# 0     ['lho', 'dia', 'yang', 'minta', 'ibu', 'kota',...
# 1     ['belum', 'jadi', 'kok', 'sudah', 'mau', 'memi...
# 2     ['sampai', 'di', 'ibu', 'kota', 'negara', 'asn...
# 3     ['emang', 'ibu', 'kota', 'negara', 'jadi', 'ka...
# 4     ['tidak', 'semudah', 'itu', 'asn', 'wajib', 'p...
# ...                                                 ...
# 8729  ['program', 'ibu', 'kota', 'negara', 'pertama'...
# 8730  ['dirangkul', 'demi', 'menyejahterakan', 'anak...
# 8731  ['rapim', 'tentara', 'nasional', 'indonesia-po...
# 8732  ['harusnya', 'para', 'gubernur', 'itu', 'bukan...
# 8733  ['siapa', 'bilang', 'kemping', 'di', 'ibu', 'k...
#
#                                        tweet_tokens_WSW  polarity_score  \
# 0     ['lho', 'kota', 'negara', 'otoritas', 'beban',...              -6
# 1     ['memindahkan', 'asn', 'kota', 'negara', 'ment...              -5
# 2     ['kota', 'negara', 'asn', 'mengeluh', 'oalah',...               6
# 3     ['emang', 'kota', 'negara', 'kayak', 'menjabat...              -4
# 4     ['semudah', 'asn', 'wajib', 'pindah', 'kota', ...              -9
# ...                                                 ...             ...
# 8729  ['program', 'kota', 'negara', 'membangun', 'ke...               0
# 8730  ['dirangkul', 'menyejahterakan', 'anak-cucu', ...               3
# 8731  ['rapim', 'tentara', 'nasional', 'indonesia-po...              -3
# 8732  ['gubernur', 'bawa', 'tanah', 'bawa', 'kas', '...              -5
# 8733  ['kemping', 'kota', 'negara', 'hasilnya', 'pen...              -2
#
#       polarity                                     positive_words  \
# 0           -1                                                 []
# 1           -1                               [('memindahkan', 1)]
# 2            1  [('kerja', 2), ('berdarah', 4), ('dengar', 2),...
# 3           -1                                                 []
# 4           -1                     [('pindah', 1), ('banget', 1)]
# ...        ...                                                ...
# 8729         0                                     [('kerja', 2)]
# 8730         1                                      [('dana', 4)]
# 8731        -1                                                 []
# 8732        -1                         [('bawa', 1), ('bawa', 1)]
# 8733        -1                                    [('goreng', 1)]
#
#                                          negative_words
# 0                         [('kota', -1), ('beban', -5)]
# 1                   [('memindahkan', -5), ('kota', -1)]
# 2     [('kota', -1), ('kena', -3), ('suara', -1), ('...
# 3                         [('kota', -1), ('kayak', -3)]
# 4     [('wajib', -2), ('pindah', -3), ('kota', -1), ...
# ...                                                 ...
# 8729                       [('kota', -1), ('kota', -1)]
# 8730                                     [('kota', -1)]
# 8731         [('kota', -1), ('kota', -1), ('kota', -1)]
# 8732         [('bawa', -3), ('bawa', -3), ('kota', -1)]
# 8733                     [('kota', -1), ('goreng', -2)]
#
# [8734 rows x 11 columns]

# %%
y_true = data['label']

# %%
y_pred = data_clus['polarity']

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score

# Menghitung akurasi
accuracy = accuracy_score(y_true, y_pred)

# Menghitung recall
# Menghitung recall dengan rata-rata 'macro'
recall = recall_score(y_true, y_pred, average='macro')

# Menghitung presisi dengan rata-rata 'macro'
precision = precision_score(y_true, y_pred, average='macro')

# Menghitung F1 score
f1 = f1_score(y_true, y_pred, average = 'macro')

accuracy_percent = round(accuracy * 100, 2)
print("Accuracy (%):", accuracy_percent)

recall_percent = format(recall * 100, ".2f")
print("Recall (%):", recall_percent)

precision_score = format(precision * 100, ".2f")
print("Precision score (%):", precision_score)

f1_percent = format(f1 * 100, ".2f")
print("F1 score (%):", f1_percent)
# Out:
# Accuracy (%): 73.6
# Recall (%): 24.53
# Precision score (%): 33.33
# F1 score (%): 28.26
# c:\Users\irfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score

# Menghitung akurasi
accuracy = accuracy_score(y_true, y_pred)

# Menghitung recall
# Menghitung recall dengan rata-rata 'macro'
recall = recall_score(y_true, y_pred, average='weighted')

# Menghitung presisi dengan rata-rata 'macro'
precision = precision_score(y_true, y_pred, average='weighted')

# Menghitung F1 score
f1 = f1_score(y_true, y_pred, average = 'weighted')

accuracy_percent = round(accuracy * 100, 2)
print("Accuracy (%):", accuracy_percent)

recall_percent = format(recall * 100, ".2f")
print("Recall (%):", recall_percent)

precision_score = format(precision * 100, ".2f")
print("Precision score (%):", precision_score)

f1_percent = format(f1 * 100, ".2f")
print("F1 score (%):", f1_percent)
# Out:
# Accuracy (%): 73.6
# Recall (%): 73.60
# Precision score (%): 100.00
# F1 score (%): 84.79
# c:\Users\irfan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
