# %%
import csv
import re
import unicodedata
from collections import defaultdict

# %%
# Load data
def read_csv(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        return list(reader)

data = read_csv('gabung_all.csv')

# %%
# Check if 'text' is in data columns
if 'text' in data[0]:
    # Extract 'text' column from data
    kolom_case_folding = [row['text'] for row in data]

    # Function to separate hashtags
    def pisahkan_hashtag(kalimat):
        pola = r'#[A-Za-z0-9_]+'
        hasil = re.findall(pola, kalimat)
        for hashtag in hasil:
            kata_terpisah = re.sub(r'([a-z])([A-Z])', r'\1 \2', hashtag)
            kalimat = kalimat.replace(hashtag, kata_terpisah)
        return kalimat

    # Separate hashtags in each sentence in 'text' column
    for row in data:
        row['pisah_hashtag&kata'] = pisahkan_hashtag(row['text'])

else:
    print("Kolom 'text' tidak ada dalam dataframe.")

# %%
# Save results to CSV
def write_csv(file_path, data):
    with open(file_path, 'w', encoding='utf-8', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=data[0].keys())
        writer.writeheader()
        writer.writerows(data)

write_csv("no_library/handling_hashtag.csv", data)

# %%
# Function to remove non-ASCII characters
def remove_non_ascii(text):
    return ''.join(c for c in unicodedata.normalize('NFKD', text) if unicodedata.category(c) != 'Mn')

# Function to preprocess text
def preprocess_text(text):
    text = remove_non_ascii(text)
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    text = re.sub(r'\@\w+|\#', '', text)
    kata_kata = text.split()
    kata_kata_tanpa_tanda_baca = [re.sub(r'[^\w\s-]', '', kata) for kata in kata_kata]
    kalimat_tanpa_tanda_baca = ' '.join(kata_kata_tanpa_tanda_baca)
    kalimat_final = re.sub(r'(?<=[^\w\s-])', ' ', kalimat_tanpa_tanda_baca)
    kalimat_tanpa_spasi_ganda = re.sub(r'\s+', ' ', kalimat_final)
    kalimat_tanpa_tanda_baca_dan_digit = re.sub(r'[^\w\s-]', '', kalimat_tanpa_spasi_ganda)
    kalimat_tanpa_digit = re.sub(r'\d+', '', kalimat_tanpa_tanda_baca_dan_digit)
    kalimat_final = kalimat_tanpa_digit.lower()
    kalimat_final = kalimat_final.strip()
    kalimat_final = re.sub(r"\b[a-zA-Z]\b", "", kalimat_final)
    return kalimat_final

# Preprocess text column
for row in data:
    row['text_cleaning'] = preprocess_text(row['pisah_hashtag&kata'])

# %%
# Normalisasi teks menggunakan kamus slang dari file
filename = "Final_1.txt"

with open(filename, "r", encoding='utf-8') as file:
    contents = file.read()
    slangs_dict = eval(contents)

def normalisasi_text(text, slangs):
    for slang, normal in slangs.items():
        pattern = r"\b{}\b".format(re.escape(slang))
        text = re.sub(pattern, normal, text)
    return text

# Apply normalization to the text_cleaning column
for row in data:
    row['text_normalisasi'] = normalisasi_text(row['text_cleaning'], slangs_dict)

# %%
# Tokenize words
def word_tokenize(text):
    return text.split()

for row in data:
    row['tweet_tokens'] = word_tokenize(row['text_normalisasi'])
    
print('Tokenizing Result : \n') 
for row in data[:5]:
    print(row['tweet_tokens'])
# Out:
# Tokenizing Result :
#
# ['lho', 'dia', 'yang', 'minta', 'ibu', 'kota', 'negara', 'kok', 'otoritas', 'di', 'beban', 'iya', 'modarlah']
# ['belum', 'jadi', 'kok', 'sudah', 'mau', 'memindahkan', 'asn', 'pak', 'yakin', 'kalau', 'ibu', 'kota', 'negara', 'sudah', 'jadi', 'bapak', 'masih', 'jadi', 'menteri']
# ['sampai', 'di', 'ibu', 'kota', 'negara', 'asn', 'nya', 'mengeluhoala', 'disini', 'baru', 'seminggu', 'kerja', 'kena', 'demam', 'berdarah', 'dengue', 'malaria', 'tidak', 'biasa', 'dengar', 'suara', 'monyet', 'ular', 'dan', 'kadang', 'anak', 'tidak', 'setia', 'didepan', 'rumahsabar', 'iya', 'asn']
# ['emang', 'ibu', 'kota', 'negara', 'jadi', 'kapan', 'kayak', 'dia', 'masih', 'menjabat', 'saja', 'boro-boro', 'masih', 'ada']
# ['tidak', 'semudah', 'itu', 'asn', 'wajib', 'pindah', 'ke', 'ibu', 'kota', 'negara', 'tahun', 'berapa', 'investor', 'nya', 'juga', 'kabur', 'belum', 'jaminan', 'kantor', 'siap', 'sombong', 'banget']

# %%
write_csv("no_library/Tweet_all.csv", data)

# %%
# Load lexicon
def load_lexicon(file_path):
    lexicon = dict()
    with open(file_path, 'r') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)  # Skip header row
        for row in reader:
            lexicon[row[0]] = int(row[1])
    return lexicon

lexicon_positive = load_lexicon('lexicon_positive.csv')
lexicon_negative = load_lexicon('lexicon_negative.csv')

# %%
# Function to determine sentiment polarity of tweets
def sentiment_analysis_lexicon_indonesia(text):
    score = 0
    positive_found = []
    negative_found = []
    for word in text:
        if word in lexicon_positive:
            score += lexicon_positive[word]
            positive_found.append((word, lexicon_positive[word]))
        if word in lexicon_negative:
            score += lexicon_negative[word]
            negative_found.append((word, lexicon_negative[word]))
    polarity = ''
    if score > 0:
        polarity = 'positive'
    elif score < 0:
        polarity = 'negative'
    else:
        polarity = 'neutral'
    return score, polarity, positive_found, negative_found

# Determine sentiment polarity of tweets
results = [sentiment_analysis_lexicon_indonesia(row['tweet_tokens']) for row in data]
for i, result in enumerate(results):
    data[i]['polarity_score'] = result[0]
    data[i]['polarity'] = result[1]
    data[i]['positive_words'] = result[2]
    data[i]['negative_words'] = result[3]

# %%
data
# Out:
# [{'text': 'Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Bebani!! Ya Modarlah?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Lho!!!! Dia Yg Minta IKN , Kok Otorita. Di Bebani!! Ya Modarlah?',
#   'text_cleaning': 'lho dia yg minta ikn kok otorita di bebani ya modarlah',
#   'text_normalisasi': 'lho dia yang minta ibu kota negara kok otoritas di beban iya modarlah',
#   'tweet_tokens': ['lho',
#    'dia',
#    'yang',
#    'minta',
#    'ibu',
#    'kota',
#    'negara',
#    'kok',
#    'otoritas',
#    'di',
#    'beban',
#    'iya',
#    'modarlah'],
#   'polarity_score': -15,
#   'polarity': 'negative',
#   'positive_words': [('minta', 2)],
#   'negative_words': [('dia', -3),
#    ('yang', -5),
#    ('minta', -3),
#    ('kota', -1),
#    ('beban', -5)]},
#  {'text': 'Belum jadi kok sudah mau memindahkan ASN Pak? Yakin kalau IKN sdh jadi bapak masih jadi Menteri?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Belum jadi kok sudah mau memindahkan ASN Pak? Yakin kalau IKN sdh jadi bapak masih jadi Menteri?',
#   'text_cleaning': 'belum jadi kok sudah mau memindahkan asn pak yakin kalau ikn sdh jadi bapak masih jadi menteri',
#   'text_normalisasi': 'belum jadi kok sudah mau memindahkan asn pak yakin kalau ibu kota negara sudah jadi bapak masih jadi menteri',
#   'tweet_tokens': ['belum',
#    'jadi',
#    'kok',
#    'sudah',
#    'mau',
#    'memindahkan',
#    'asn',
#    'pak',
#    'yakin',
#    'kalau',
#    'ibu',
#    'kota',
#    'negara',
#    'sudah',
#    'jadi',
#    'bapak',
#    'masih',
#    'jadi',
#    'menteri'],
#   'polarity_score': 0,
#   'polarity': 'neutral',
#   'positive_words': [('jadi', 1),
#    ('sudah', 3),
#    ('mau', 5),
#    ('memindahkan', 1),
#    ('yakin', 3),
#    ('sudah', 3),
#    ('jadi', 1),
#    ('jadi', 1)],
#   'negative_words': [('jadi', -2),
#    ('sudah', -2),
#    ('mau', -1),
#    ('memindahkan', -5),
#    ('kalau', -1),
#    ('kota', -1),
#    ('sudah', -2),
#    ('jadi', -2),
#    ('jadi', -2)]},
#  {'text': 'Sampai di IKN, asn nya mengeluh...oala disini baru seminggu kerja kena DBD, malaria ... gak biasa dengar suara monyet, ular dan kadang2 anak buaya didepan rumah...sabar ya asn',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Sampai di IKN, asn nya mengeluh...oala disini baru seminggu kerja kena DBD, malaria ... gak biasa dengar suara monyet, ular dan kadang2 anak buaya didepan rumah...sabar ya asn',
#   'text_cleaning': 'sampai di ikn asn nya mengeluhoala disini baru seminggu kerja kena dbd malaria gak biasa dengar suara monyet ular dan kadang anak buaya didepan rumahsabar ya asn',
#   'text_normalisasi': 'sampai di ibu kota negara asn nya mengeluhoala disini baru seminggu kerja kena demam berdarah dengue malaria tidak biasa dengar suara monyet ular dan kadang anak tidak setia didepan rumahsabar iya asn',
#   'tweet_tokens': ['sampai',
#    'di',
#    'ibu',
#    'kota',
#    'negara',
#    'asn',
#    'nya',
#    'mengeluhoala',
#    'disini',
#    'baru',
#    'seminggu',
#    'kerja',
#    'kena',
#    'demam',
#    'berdarah',
#    'dengue',
#    'malaria',
#    'tidak',
#    'biasa',
#    'dengar',
#    'suara',
#    'monyet',
#    'ular',
#    'dan',
#    'kadang',
#    'anak',
#    'tidak',
#    'setia',
#    'didepan',
#    'rumahsabar',
#    'iya',
#    'asn'],
#   'polarity_score': -16,
#   'polarity': 'negative',
#   'positive_words': [('sampai', 2),
#    ('kerja', 2),
#    ('berdarah', 4),
#    ('biasa', 2),
#    ('dengar', 2),
#    ('suara', 2),
#    ('kadang', 3)],
#   'negative_words': [('sampai', -4),
#    ('kota', -1),
#    ('kena', -3),
#    ('tidak', -5),
#    ('biasa', -4),
#    ('suara', -1),
#    ('monyet', -3),
#    ('anak', -3),
#    ('tidak', -5),
#    ('setia', -4)]},
#  {'text': 'Emang ikn jadi kapan? Kayak dia masih menjabat aja, boro-boro masih ada',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Emang ikn jadi kapan? Kayak dia masih menjabat aja, boro-boro masih ada',
#   'text_cleaning': 'emang ikn jadi kapan kayak dia masih menjabat aja boro-boro masih ada',
#   'text_normalisasi': 'emang ibu kota negara jadi kapan kayak dia masih menjabat saja boro-boro masih ada',
#   'tweet_tokens': ['emang',
#    'ibu',
#    'kota',
#    'negara',
#    'jadi',
#    'kapan',
#    'kayak',
#    'dia',
#    'masih',
#    'menjabat',
#    'saja',
#    'boro-boro',
#    'masih',
#    'ada'],
#   'polarity_score': -10,
#   'polarity': 'negative',
#   'positive_words': [('jadi', 1), ('ada', 4)],
#   'negative_words': [('kota', -1),
#    ('jadi', -2),
#    ('kayak', -3),
#    ('dia', -3),
#    ('saja', -3),
#    ('ada', -3)]},
#  {'text': 'Tdk semudah itu ASN wajib pindah ke IKN tahun berapa. Investor nya jg kaboor. Blm jaminan kantor2 2024 siap\nSombong banget',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Tdk semudah itu ASN wajib pindah ke IKN tahun berapa. Investor nya jg kaboor. Blm jaminan kantor2 2024 siap\nSombong banget',
#   'text_cleaning': 'tdk semudah itu asn wajib pindah ke ikn tahun berapa investor nya jg kaboor blm jaminan kantor  siap sombong banget',
#   'text_normalisasi': 'tidak semudah itu asn wajib pindah ke ibu kota negara tahun berapa investor nya juga kabur belum jaminan kantor  siap sombong banget',
#   'tweet_tokens': ['tidak',
#    'semudah',
#    'itu',
#    'asn',
#    'wajib',
#    'pindah',
#    'ke',
#    'ibu',
#    'kota',
#    'negara',
#    'tahun',
#    'berapa',
#    'investor',
#    'nya',
#    'juga',
#    'kabur',
#    'belum',
#    'jaminan',
#    'kantor',
#    'siap',
#    'sombong',
#    'banget'],
#   'polarity_score': -15,
#   'polarity': 'negative',
#   'positive_words': [('pindah', 1), ('siap', 1), ('banget', 1)],
#   'negative_words': [('tidak', -5),
#    ('itu', -2),
#    ('wajib', -2),
#    ('pindah', -3),
#    ('kota', -1),
#    ('kabur', -2),
#    ('sombong', -3)]},
#  {'text': 'Gak akan dapat IKN tak jelas.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Gak akan dapat IKN tak jelas.',
#   'text_cleaning': 'gak akan dapat ikn tak jelas',
#   'text_normalisasi': 'tidak akan dapat ibu kota negara tidak jelas',
#   'tweet_tokens': ['tidak',
#    'akan',
#    'dapat',
#    'ibu',
#    'kota',
#    'negara',
#    'tidak',
#    'jelas'],
#   'polarity_score': -13,
#   'polarity': 'negative',
#   'positive_words': [('dapat', 2), ('jelas', 1)],
#   'negative_words': [('tidak', -5),
#    ('dapat', -2),
#    ('kota', -1),
#    ('tidak', -5),
#    ('jelas', -3)]},
#  {'text': 'Lu yakin IKN bakal mulus..?\nHalu lu sama keq junjungan lu..',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Lu yakin IKN bakal mulus..?\nHalu lu sama keq junjungan lu..',
#   'text_cleaning': 'lu yakin ikn bakal mulus halu lu sama keq junjungan lu',
#   'text_normalisasi': 'kamu yakin ibu kota negara bakal mulus halu kamu sama seperti junjungan kamu',
#   'tweet_tokens': ['kamu',
#    'yakin',
#    'ibu',
#    'kota',
#    'negara',
#    'bakal',
#    'mulus',
#    'halu',
#    'kamu',
#    'sama',
#    'seperti',
#    'junjungan',
#    'kamu'],
#   'polarity_score': 1,
#   'polarity': 'positive',
#   'positive_words': [('yakin', 3), ('mulus', 4), ('sama', 3)],
#   'negative_words': [('kota', -1),
#    ('mulus', -5),
#    ('seperti', -1),
#    ('junjungan', -2)]},
#  {'text': 'Semoga hanya diberi angin Surga saja ..wkwkwkwkwk\nAmbyaaaar itu proyect IKN kurang Dana...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Semoga hanya diberi angin Surga saja ..wkwkwkwkwk\nAmbyaaaar itu proyect IKN kurang Dana...',
#   'text_cleaning': 'semoga hanya diberi angin surga saja wkwkwkwkwk ambyaaaar itu proyect ikn kurang dana',
#   'text_normalisasi': 'semoga hanya diberi angin surga saja wkwkwkwkwk ambyar itu proyek ibu kota negara kurang dana',
#   'tweet_tokens': ['semoga',
#    'hanya',
#    'diberi',
#    'angin',
#    'surga',
#    'saja',
#    'wkwkwkwkwk',
#    'ambyar',
#    'itu',
#    'proyek',
#    'ibu',
#    'kota',
#    'negara',
#    'kurang',
#    'dana'],
#   'polarity_score': -8,
#   'polarity': 'negative',
#   'positive_words': [('dana', 4)],
#   'negative_words': [('hanya', -3),
#    ('saja', -3),
#    ('itu', -2),
#    ('kota', -1),
#    ('kurang', -3)]},
#  {'text': 'pendukung IKN dan buzzerRp pasa pindah duluan dah sono. kantor PBNU ANSOR BANSER buruan hijrah. \n@PBNU_164',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'pendukung IKN dan buzzerRp pasa pindah duluan dah sono. kantor PBNU ANSOR BANSER buruan hijrah. \n@PBNU_164',
#   'text_cleaning': 'pendukung ikn dan buzzerrp pasa pindah duluan dah sono kantor pbnu ansor banser buruan hijrah',
#   'text_normalisasi': 'pendukung ibu kota negara dan buzzer rupiah pasca pindah duluan deh sana kantor pengurus besar nahdlatul ulama ansor banser buruan hijrah',
#   'tweet_tokens': ['pendukung',
#    'ibu',
#    'kota',
#    'negara',
#    'dan',
#    'buzzer',
#    'rupiah',
#    'pasca',
#    'pindah',
#    'duluan',
#    'deh',
#    'sana',
#    'kantor',
#    'pengurus',
#    'besar',
#    'nahdlatul',
#    'ulama',
#    'ansor',
#    'banser',
#    'buruan',
#    'hijrah'],
#   'polarity_score': 10,
#   'polarity': 'positive',
#   'positive_words': [('pendukung', 4),
#    ('pindah', 1),
#    ('duluan', 2),
#    ('pengurus', 3),
#    ('besar', 4),
#    ('ulama', 3),
#    ('buruan', 1)],
#   'negative_words': [('kota', -1),
#    ('pindah', -3),
#    ('duluan', -2),
#    ('besar', -2)]},
#  {'text': 'Kalau utk urusan rakyat mana mau Pmrnth berikan subsidi … tp kalau utk proyek inftastruktur, IKN, APBN siap digelontorkan.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Kalau utk urusan rakyat mana mau Pmrnth berikan subsidi … tp kalau utk proyek inftastruktur, IKN, APBN siap digelontorkan.',
#   'text_cleaning': 'kalau utk urusan rakyat mana mau pmrnth berikan subsidi tp kalau utk proyek inftastruktur ikn apbn siap digelontorkan',
#   'text_normalisasi': 'kalau untuk urusan rakyat mana mau pemerintah berikan subsidi tapi kalau untuk proyek infrastruktur ibu kota negara anggaran pendapatan dan belanja negara siap digelontorkan',
#   'tweet_tokens': ['kalau',
#    'untuk',
#    'urusan',
#    'rakyat',
#    'mana',
#    'mau',
#    'pemerintah',
#    'berikan',
#    'subsidi',
#    'tapi',
#    'kalau',
#    'untuk',
#    'proyek',
#    'infrastruktur',
#    'ibu',
#    'kota',
#    'negara',
#    'anggaran',
#    'pendapatan',
#    'dan',
#    'belanja',
#    'negara',
#    'siap',
#    'digelontorkan'],
#   'polarity_score': 0,
#   'polarity': 'neutral',
#   'positive_words': [('mau', 5),
#    ('pendapatan', 2),
#    ('belanja', 2),
#    ('siap', 1)],
#   'negative_words': [('kalau', -1),
#    ('mau', -1),
#    ('kalau', -1),
#    ('kota', -1),
#    ('pendapatan', -3),
#    ('belanja', -3)]},
#  {'text': 'Merehabilitasi hutan???.bukannya hutannya ditebang mau dijadikan IKN..',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Merehabilitasi hutan???.bukannya hutannya ditebang mau dijadikan IKN..',
#   'text_cleaning': 'merehabilitasi hutanbukannya hutannya ditebang mau dijadikan ikn',
#   'text_normalisasi': 'merehabilitasi hutanbukannya hutannya ditebang mau dijadikan ibu kota negara',
#   'tweet_tokens': ['merehabilitasi',
#    'hutanbukannya',
#    'hutannya',
#    'ditebang',
#    'mau',
#    'dijadikan',
#    'ibu',
#    'kota',
#    'negara'],
#   'polarity_score': 3,
#   'polarity': 'positive',
#   'positive_words': [('mau', 5)],
#   'negative_words': [('mau', -1), ('kota', -1)]},
#  {'text': 'Rasa-rasanya IKN masih hutan aja si Tjahjo udah dikeluarin duluan sama Izro’il Prof…',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Rasa-rasanya IKN masih hutan aja si Tjahjo udah dikeluarin duluan sama Izro’il Prof…',
#   'text_cleaning': 'rasa-rasanya ikn masih hutan aja si tjahjo udah dikeluarin duluan sama izroil prof',
#   'text_normalisasi': 'rasa-rasanya ibu kota negara masih hutan saja si tjahjo sudah dikeluarkan duluan sama izroil profesor',
#   'tweet_tokens': ['rasa-rasanya',
#    'ibu',
#    'kota',
#    'negara',
#    'masih',
#    'hutan',
#    'saja',
#    'si',
#    'tjahjo',
#    'sudah',
#    'dikeluarkan',
#    'duluan',
#    'sama',
#    'izroil',
#    'profesor'],
#   'polarity_score': 3,
#   'polarity': 'positive',
#   'positive_words': [('hutan', 3), ('sudah', 3), ('duluan', 2), ('sama', 3)],
#   'negative_words': [('kota', -1),
#    ('saja', -3),
#    ('sudah', -2),
#    ('duluan', -2)]},
#  {'text': 'Bayak burung2,  binatang langka dan tumbuhan2 langka  yg akan hilang. Jika ikn benar2 jadi dipindahkan, ingat dulu rajaampat sudah diperingatkan terumbukarangnya akan rusak jika di buka wisata. Akhirnya beneran terjadi kan. Belajarlah dari kasalahan2 sebelumnya.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Bayak burung2,  binatang langka dan tumbuhan2 langka  yg akan hilang. Jika ikn benar2 jadi dipindahkan, ingat dulu rajaampat sudah diperingatkan terumbukarangnya akan rusak jika di buka wisata. Akhirnya beneran terjadi kan. Belajarlah dari kasalahan2 sebelumnya.',
#   'text_cleaning': 'bayak burung binatang langka dan tumbuhan langka yg akan hilang jika ikn benar jadi dipindahkan ingat dulu rajaampat sudah diperingatkan terumbukarangnya akan rusak jika di buka wisata akhirnya beneran terjadi kan belajarlah dari kasalahan sebelumnya',
#   'text_normalisasi': 'bayak burung binatang langka dan tumbuhan langka yang akan hilang jika ibu kota negara benar jadi dipindahkan ingat dulu raja ampat sudah diperingatkan terumbukarangnya akan rusak jika di buka wisata akhirnya beneran terjadi kan belajarlah dari kasalahan sebelumnya',
#   'tweet_tokens': ['bayak',
#    'burung',
#    'binatang',
#    'langka',
#    'dan',
#    'tumbuhan',
#    'langka',
#    'yang',
#    'akan',
#    'hilang',
#    'jika',
#    'ibu',
#    'kota',
#    'negara',
#    'benar',
#    'jadi',
#    'dipindahkan',
#    'ingat',
#    'dulu',
#    'raja',
#    'ampat',
#    'sudah',
#    'diperingatkan',
#    'terumbukarangnya',
#    'akan',
#    'rusak',
#    'jika',
#    'di',
#    'buka',
#    'wisata',
#    'akhirnya',
#    'beneran',
#    'terjadi',
#    'kan',
#    'belajarlah',
#    'dari',
#    'kasalahan',
#    'sebelumnya'],
#   'polarity_score': -18,
#   'polarity': 'negative',
#   'positive_words': [('hilang', 3),
#    ('benar', 2),
#    ('jadi', 1),
#    ('ingat', 2),
#    ('sudah', 3),
#    ('rusak', 3),
#    ('buka', 3),
#    ('beneran', 3),
#    ('terjadi', 3)],
#   'negative_words': [('langka', -5),
#    ('langka', -5),
#    ('yang', -5),
#    ('hilang', -4),
#    ('kota', -1),
#    ('benar', -4),
#    ('jadi', -2),
#    ('ingat', -3),
#    ('sudah', -2),
#    ('rusak', -4),
#    ('buka', -3),
#    ('dari', -3)]},
#  {'text': 'Insinyur kehutanan siluman yang merusak hutan kalimantan ratusan ribu hektar demi ambisi menambah hutang negara untuk sebuah proyek bernama Ibukota Klenik Nusantara. Taruhan berapa IKN mogok alias mangkrak alias bangkrut..!?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Insinyur kehutanan siluman yang merusak hutan kalimantan ratusan ribu hektar demi ambisi menambah hutang negara untuk sebuah proyek bernama Ibukota Klenik Nusantara. Taruhan berapa IKN mogok alias mangkrak alias bangkrut..!?',
#   'text_cleaning': 'insinyur kehutanan siluman yang merusak hutan kalimantan ratusan ribu hektar demi ambisi menambah hutang negara untuk sebuah proyek bernama ibukota klenik nusantara taruhan berapa ikn mogok alias mangkrak alias bangkrut',
#   'text_normalisasi': 'insinyur kehutanan siluman yang merusak hutan kalimantan ratusan ribu hektar demi ambisi menambah hutang negara untuk sebuah proyek bernama ibu kota klenik nusantara taruhan berapa ibu kota negara mogok alias terbengkalai alias bangkrut',
#   'tweet_tokens': ['insinyur',
#    'kehutanan',
#    'siluman',
#    'yang',
#    'merusak',
#    'hutan',
#    'kalimantan',
#    'ratusan',
#    'ribu',
#    'hektar',
#    'demi',
#    'ambisi',
#    'menambah',
#    'hutang',
#    'negara',
#    'untuk',
#    'sebuah',
#    'proyek',
#    'bernama',
#    'ibu',
#    'kota',
#    'klenik',
#    'nusantara',
#    'taruhan',
#    'berapa',
#    'ibu',
#    'kota',
#    'negara',
#    'mogok',
#    'alias',
#    'terbengkalai',
#    'alias',
#    'bangkrut'],
#   'polarity_score': -10,
#   'polarity': 'negative',
#   'positive_words': [('hutan', 3),
#    ('ambisi', 4),
#    ('menambah', 3),
#    ('bernama', 4),
#    ('taruhan', 3)],
#   'negative_words': [('siluman', -5),
#    ('yang', -5),
#    ('hutang', -5),
#    ('kota', -1),
#    ('kota', -1),
#    ('mogok', -5),
#    ('bangkrut', -5)]},
#  {'text': 'Bp wapres ko tenang" aja kagak kedengaran suaranya padahal ada pendeta  minta hapus 300 ayat Al-Quran.. kemping di ikn ga keliatan..juga masalah migor adem ayem \nSemoga pa Yai sehat selalu Aamiin',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Bp wapres ko tenang" aja kagak kedengaran suaranya padahal ada pendeta  minta hapus 300 ayat Al-Quran.. kemping di ikn ga keliatan..juga masalah migor adem ayem \nSemoga pa Yai sehat selalu Aamiin',
#   'text_cleaning': 'bp wapres ko tenang aja kagak kedengaran suaranya padahal ada pendeta minta hapus  ayat al-quran kemping di ikn ga keliatanjuga masalah migor adem ayem semoga pa yai sehat selalu aamiin',
#   'text_normalisasi': 'bapak wakil presiden ko tenangsaja tidak kedengaran suaranya padahal ada pendeta minta hapus  ayat al-quran kemping di ibu kota negara tidak keliatanjuga masalah minyak goreng adem ayem semoga pa iya sehat selalu aamiin',
#   'tweet_tokens': ['bapak',
#    'wakil',
#    'presiden',
#    'ko',
#    'tenangsaja',
#    'tidak',
#    'kedengaran',
#    'suaranya',
#    'padahal',
#    'ada',
#    'pendeta',
#    'minta',
#    'hapus',
#    'ayat',
#    'al-quran',
#    'kemping',
#    'di',
#    'ibu',
#    'kota',
#    'negara',
#    'tidak',
#    'keliatanjuga',
#    'masalah',
#    'minyak',
#    'goreng',
#    'adem',
#    'ayem',
#    'semoga',
#    'pa',
#    'iya',
#    'sehat',
#    'selalu',
#    'aamiin'],
#   'polarity_score': -20,
#   'polarity': 'negative',
#   'positive_words': [('presiden', 3),
#    ('ada', 4),
#    ('minta', 2),
#    ('goreng', 1),
#    ('sehat', 4),
#    ('aamiin', 2)],
#   'negative_words': [('tidak', -5),
#    ('ada', -3),
#    ('minta', -3),
#    ('hapus', -3),
#    ('ayat', -4),
#    ('kota', -1),
#    ('tidak', -5),
#    ('masalah', -4),
#    ('goreng', -2),
#    ('pa', -5),
#    ('sehat', -1)]},
#  {'text': 'Hayoo..ASN, 2024 masih pilih yg memaksa ke IKN ??',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Hayoo..ASN, 2024 masih pilih yg memaksa ke IKN ??',
#   'text_cleaning': 'hayooasn  masih pilih yg memaksa ke ikn',
#   'text_normalisasi': 'hayooasn  masih pilih yang memaksa ke ibu kota negara',
#   'tweet_tokens': ['hayooasn',
#    'masih',
#    'pilih',
#    'yang',
#    'memaksa',
#    'ke',
#    'ibu',
#    'kota',
#    'negara'],
#   'polarity_score': -8,
#   'polarity': 'negative',
#   'positive_words': [],
#   'negative_words': [('pilih', -2), ('yang', -5), ('kota', -1)]},
#  {'text': 'Cina diprediksi akan menyerang/invasi Taiwan di musim gugur (Agustus-September) tahun ini.\nJangan hanya sibuk urus IKN dan minyak goreng aja. Better be prepared for the worst...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Cina diprediksi akan menyerang/invasi Taiwan di musim gugur (Agustus-September) tahun ini.\nJangan hanya sibuk urus IKN dan minyak goreng aja. Better be prepared for the worst...',
#   'text_cleaning': 'cina diprediksi akan menyeranginvasi taiwan di musim gugur agustus-september tahun ini jangan hanya sibuk urus ikn dan minyak goreng aja better be prepared for the worst',
#   'text_normalisasi': 'cina diprediksi akan menyeranginvasi taiwan di musim gugur agustus-september tahun ini jangan hanya sibuk urus ibu kota negara dan minyak goreng saja lebih baik be siap for the terburuk',
#   'tweet_tokens': ['cina',
#    'diprediksi',
#    'akan',
#    'menyeranginvasi',
#    'taiwan',
#    'di',
#    'musim',
#    'gugur',
#    'agustus-september',
#    'tahun',
#    'ini',
#    'jangan',
#    'hanya',
#    'sibuk',
#    'urus',
#    'ibu',
#    'kota',
#    'negara',
#    'dan',
#    'minyak',
#    'goreng',
#    'saja',
#    'lebih',
#    'baik',
#    'be',
#    'siap',
#    'for',
#    'the',
#    'terburuk'],
#   'polarity_score': -8,
#   'polarity': 'negative',
#   'positive_words': [('gugur', 1),
#    ('sibuk', 4),
#    ('goreng', 1),
#    ('lebih', 1),
#    ('baik', 3),
#    ('siap', 1)],
#   'negative_words': [('gugur', -3),
#    ('jangan', -3),
#    ('hanya', -3),
#    ('sibuk', -3),
#    ('kota', -1),
#    ('goreng', -2),
#    ('saja', -3),
#    ('baik', -1)]},
#  {'text': 'Palingan IKN belum apa2 sudah ganti rezim',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Palingan IKN belum apa2 sudah ganti rezim',
#   'text_cleaning': 'palingan ikn belum apa sudah ganti rezim',
#   'text_normalisasi': 'palingan ibu kota negara belum apa sudah ganti rezim',
#   'tweet_tokens': ['palingan',
#    'ibu',
#    'kota',
#    'negara',
#    'belum',
#    'apa',
#    'sudah',
#    'ganti',
#    'rezim'],
#   'polarity_score': -3,
#   'polarity': 'negative',
#   'positive_words': [('sudah', 3), ('ganti', 3)],
#   'negative_words': [('kota', -1), ('apa', -3), ('sudah', -2), ('ganti', -3)]},
#  {'text': 'Kalau IKN dah jadi dan fasilitasnya sudah lengkap pasti pada mau.\n\nKalau sekarang suruh pindah, disana suruh ngapain.\n\nYang disana gak ada semalam saja sudah gak betah',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Kalau IKN dah jadi dan fasilitasnya sudah lengkap pasti pada mau.\n\nKalau sekarang suruh pindah, disana suruh ngapain.\n\nYang disana gak ada semalam saja sudah gak betah',
#   'text_cleaning': 'kalau ikn dah jadi dan fasilitasnya sudah lengkap pasti pada mau kalau sekarang suruh pindah disana suruh ngapain yang disana gak ada semalam saja sudah gak betah',
#   'text_normalisasi': 'kalau ibu kota negara deh jadi dan fasilitasnya sudah lengkap pasti pada mau kalau sekarang suruh pindah disana suruh sedang apa yang disana tidak ada semalam saja sudah tidak betah',
#   'tweet_tokens': ['kalau',
#    'ibu',
#    'kota',
#    'negara',
#    'deh',
#    'jadi',
#    'dan',
#    'fasilitasnya',
#    'sudah',
#    'lengkap',
#    'pasti',
#    'pada',
#    'mau',
#    'kalau',
#    'sekarang',
#    'suruh',
#    'pindah',
#    'disana',
#    'suruh',
#    'sedang',
#    'apa',
#    'yang',
#    'disana',
#    'tidak',
#    'ada',
#    'semalam',
#    'saja',
#    'sudah',
#    'tidak',
#    'betah'],
#   'polarity_score': -25,
#   'polarity': 'negative',
#   'positive_words': [('jadi', 1),
#    ('sudah', 3),
#    ('lengkap', 2),
#    ('pasti', 3),
#    ('mau', 5),
#    ('pindah', 1),
#    ('ada', 4),
#    ('sudah', 3)],
#   'negative_words': [('kalau', -1),
#    ('kota', -1),
#    ('jadi', -2),
#    ('sudah', -2),
#    ('lengkap', -3),
#    ('pada', -3),
#    ('mau', -1),
#    ('kalau', -1),
#    ('suruh', -2),
#    ('pindah', -3),
#    ('suruh', -2),
#    ('apa', -3),
#    ('yang', -5),
#    ('tidak', -5),
#    ('ada', -3),
#    ('saja', -3),
#    ('sudah', -2),
#    ('tidak', -5)]},
#  {'text': 'Kalo enak, ya silahkan anda pindah ke IKN.\nKalo kami sih jauh, kayak dari ujung kulon ke Surabaya.\nDan kami disini yg tidak setuju, memang sudah merasa nyaman akan daerah kami tanpa hiruk pikuk embel2 ibu kota.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Kalo enak, ya silahkan anda pindah ke IKN.\nKalo kami sih jauh, kayak dari ujung kulon ke Surabaya.\nDan kami disini yg tidak setuju, memang sudah merasa nyaman akan daerah kami tanpa hiruk pikuk embel2 ibu kota.',
#   'text_cleaning': 'kalo enak ya silahkan anda pindah ke ikn kalo kami sih jauh kayak dari ujung kulon ke surabaya dan kami disini yg tidak setuju memang sudah merasa nyaman akan daerah kami tanpa hiruk pikuk embel ibu kota',
#   'text_normalisasi': 'kalau enak iya silahkan anda pindah ke ibu kota negara kalau kami sih jauh kayak dari ujung kulon ke surabaya dan kami disini yang tidak setuju memang sudah merasa nyaman akan daerah kami tanpa hiruk gempar embel ibu kota',
#   'tweet_tokens': ['kalau',
#    'enak',
#    'iya',
#    'silahkan',
#    'anda',
#    'pindah',
#    'ke',
#    'ibu',
#    'kota',
#    'negara',
#    'kalau',
#    'kami',
#    'sih',
#    'jauh',
#    'kayak',
#    'dari',
#    'ujung',
#    'kulon',
#    'ke',
#    'surabaya',
#    'dan',
#    'kami',
#    'disini',
#    'yang',
#    'tidak',
#    'setuju',
#    'memang',
#    'sudah',
#    'merasa',
#    'nyaman',
#    'akan',
#    'daerah',
#    'kami',
#    'tanpa',
#    'hiruk',
#    'gempar',
#    'embel',
#    'ibu',
#    'kota'],
#   'polarity_score': -21,
#   'polarity': 'negative',
#   'positive_words': [('enak', 5),
#    ('silahkan', 3),
#    ('pindah', 1),
#    ('setuju', 4),
#    ('memang', 4),
#    ('sudah', 3),
#    ('nyaman', 4),
#    ('hiruk', 1),
#    ('gempar', 4)],
#   'negative_words': [('kalau', -1),
#    ('enak', -4),
#    ('anda', -1),
#    ('pindah', -3),
#    ('kota', -1),
#    ('kalau', -1),
#    ('jauh', -4),
#    ('kayak', -3),
#    ('dari', -3),
#    ('ujung', -3),
#    ('yang', -5),
#    ('tidak', -5),
#    ('setuju', -3),
#    ('memang', -2),
#    ('sudah', -2),
#    ('merasa', -2),
#    ('hiruk', -4),
#    ('gempar', -2),
#    ('kota', -1)]},
#  {'text': 'Pemindahan IKN tanda akhir zaman',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Pemindahan IKN tanda akhir zaman',
#   'text_cleaning': 'pemindahan ikn tanda akhir zaman',
#   'text_normalisasi': 'pemindahan ibu kota negara tanda akhir zaman',
#   'tweet_tokens': ['pemindahan',
#    'ibu',
#    'kota',
#    'negara',
#    'tanda',
#    'akhir',
#    'zaman'],
#   'polarity_score': -3,
#   'polarity': 'negative',
#   'positive_words': [],
#   'negative_words': [('kota', -1), ('tanda', -2)]},
#  {'text': 'Klu nggak salah, Rasulullah hijrahnya ke Madinah yg merupakan kota. Kok pindah  IKN ke tengah hutan disepertikan hijrah Rasulullah...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Klu nggak salah, Rasulullah hijrahnya ke Madinah yg merupakan kota. Kok pindah  IKN ke tengah hutan disepertikan hijrah Rasulullah...',
#   'text_cleaning': 'klu nggak salah rasulullah hijrahnya ke madinah yg merupakan kota kok pindah ikn ke tengah hutan disepertikan hijrah rasulullah',
#   'text_normalisasi': 'kalau tidak salah rasulullah hijrahnya ke madinah yang merupakan kota kok pindah ibu kota negara ke tengah hutan disamakan hijrah rasulullah',
#   'tweet_tokens': ['kalau',
#    'tidak',
#    'salah',
#    'rasulullah',
#    'hijrahnya',
#    'ke',
#    'madinah',
#    'yang',
#    'merupakan',
#    'kota',
#    'kok',
#    'pindah',
#    'ibu',
#    'kota',
#    'negara',
#    'ke',
#    'tengah',
#    'hutan',
#    'disamakan',
#    'hijrah',
#    'rasulullah'],
#   'polarity_score': -14,
#   'polarity': 'negative',
#   'positive_words': [('pindah', 1), ('tengah', 2), ('hutan', 3)],
#   'negative_words': [('kalau', -1),
#    ('tidak', -5),
#    ('salah', -4),
#    ('yang', -5),
#    ('kota', -1),
#    ('pindah', -3),
#    ('kota', -1)]},
#  {'text': 'Krn memang sdh hbs masa jabatannya dan sdh 2 periode.\n\nHayolah pak, jgn gara² IKN bpk bikin statemen yg membodohi rakyat. \nApa bapak mau ngajarin rakyat melanggar konstitusi?\n\nSemoga tidak ada upaya utk menggolkan penundaan pemilu, perpanjangan masa jabatan, ato 3 periode. Aamiin',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Krn memang sdh hbs masa jabatannya dan sdh 2 periode.\n\nHayolah pak, jgn gara² IKN bpk bikin statemen yg membodohi rakyat. \nApa bapak mau ngajarin rakyat melanggar konstitusi?\n\nSemoga tidak ada upaya utk menggolkan penundaan pemilu, perpanjangan masa jabatan, ato 3 periode. Aamiin',
#   'text_cleaning': 'krn memang sdh hbs masa jabatannya dan sdh  periode hayolah pak jgn gara ikn bpk bikin statemen yg membodohi rakyat apa bapak mau ngajarin rakyat melanggar konstitusi semoga tidak ada upaya utk menggolkan penundaan pemilu perpanjangan masa jabatan ato  periode aamiin',
#   'text_normalisasi': 'karena memang sudah habis masa jabatannya dan sudah  periode ayolah pak jangan gara ibu kota negara bapak bikin statemen yang membodohi rakyat apa bapak mau mengajarkan rakyat melanggar konstitusi semoga tidak ada upaya untuk menggolkan penundaan pemilu perpanjangan masa jabatan atau  periode aamiin',
#   'tweet_tokens': ['karena',
#    'memang',
#    'sudah',
#    'habis',
#    'masa',
#    'jabatannya',
#    'dan',
#    'sudah',
#    'periode',
#    'ayolah',
#    'pak',
#    'jangan',
#    'gara',
#    'ibu',
#    'kota',
#    'negara',
#    'bapak',
#    'bikin',
#    'statemen',
#    'yang',
#    'membodohi',
#    'rakyat',
#    'apa',
#    'bapak',
#    'mau',
#    'mengajarkan',
#    'rakyat',
#    'melanggar',
#    'konstitusi',
#    'semoga',
#    'tidak',
#    'ada',
#    'upaya',
#    'untuk',
#    'menggolkan',
#    'penundaan',
#    'pemilu',
#    'perpanjangan',
#    'masa',
#    'jabatan',
#    'atau',
#    'periode',
#    'aamiin'],
#   'polarity_score': -19,
#   'polarity': 'negative',
#   'positive_words': [('memang', 4),
#    ('sudah', 3),
#    ('habis', 3),
#    ('sudah', 3),
#    ('mau', 5),
#    ('ada', 4),
#    ('upaya', 1),
#    ('perpanjangan', 2),
#    ('aamiin', 2)],
#   'negative_words': [('karena', -3),
#    ('memang', -2),
#    ('sudah', -2),
#    ('habis', -3),
#    ('sudah', -2),
#    ('jangan', -3),
#    ('gara', -4),
#    ('kota', -1),
#    ('yang', -5),
#    ('apa', -3),
#    ('mau', -1),
#    ('melanggar', -5),
#    ('tidak', -5),
#    ('ada', -3),
#    ('upaya', -4)]},
#  {'text': 'Setelah habis kemping di IKN akhirnya harga minyak ditetapkan...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Setelah habis kemping di IKN akhirnya harga minyak ditetapkan...',
#   'text_cleaning': 'setelah habis kemping di ikn akhirnya harga minyak ditetapkan',
#   'text_normalisasi': 'setelah habis kemping di ibu kota negara akhirnya harga minyak ditetapkan',
#   'tweet_tokens': ['setelah',
#    'habis',
#    'kemping',
#    'di',
#    'ibu',
#    'kota',
#    'negara',
#    'akhirnya',
#    'harga',
#    'minyak',
#    'ditetapkan'],
#   'polarity_score': 2,
#   'polarity': 'positive',
#   'positive_words': [('habis', 3), ('harga', 3)],
#   'negative_words': [('habis', -3), ('kota', -1)]},
#  {'text': 'Apo ado hubungannya DG bawa tanah minang ke ikn ?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Apo ado hubungannya DG bawa tanah minang ke ikn ?',
#   'text_cleaning': 'apo ado hubungannya dg bawa tanah minang ke ikn',
#   'text_normalisasi': 'apa ada hubungannya dengan bawa tanah minang ke ibu kota negara',
#   'tweet_tokens': ['apa',
#    'ada',
#    'hubungannya',
#    'dengan',
#    'bawa',
#    'tanah',
#    'minang',
#    'ke',
#    'ibu',
#    'kota',
#    'negara'],
#   'polarity_score': -5,
#   'polarity': 'negative',
#   'positive_words': [('ada', 4), ('bawa', 1)],
#   'negative_words': [('apa', -3), ('ada', -3), ('bawa', -3), ('kota', -1)]},
#  {'text': 'Gaada unta emang bisa jadi IKN?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Gaada unta emang bisa jadi IKN?',
#   'text_cleaning': 'gaada unta emang bisa jadi ikn',
#   'text_normalisasi': 'tidak ada uang unta emang bisa jadi ibu kota negara',
#   'tweet_tokens': ['tidak',
#    'ada',
#    'uang',
#    'unta',
#    'emang',
#    'bisa',
#    'jadi',
#    'ibu',
#    'kota',
#    'negara'],
#   'polarity_score': -6,
#   'polarity': 'negative',
#   'positive_words': [('ada', 4), ('jadi', 1)],
#   'negative_words': [('tidak', -5), ('ada', -3), ('jadi', -2), ('kota', -1)]},
#  {'text': 'Lantas yang tempohari ngamuk2 sampe ada yg pamer mandau terbang segala untuk menanantang penentang penetapan IKN disana, siapa dan dari kelompok mana ?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Lantas yang tempohari ngamuk2 sampe ada yg pamer mandau terbang segala untuk menanantang penentang penetapan IKN disana, siapa dan dari kelompok mana ?',
#   'text_cleaning': 'lantas yang tempohari ngamuk sampe ada yg pamer mandau terbang segala untuk menanantang penentang penetapan ikn disana siapa dan dari kelompok mana',
#   'text_normalisasi': 'lantas yang tempo hari ngamuk sampai ada yang pamer mandau terbang segala untuk menantang penentang penetapan ibu kota negara disana siapa dan dari kelompok mana',
#   'tweet_tokens': ['lantas',
#    'yang',
#    'tempo',
#    'hari',
#    'ngamuk',
#    'sampai',
#    'ada',
#    'yang',
#    'pamer',
#    'mandau',
#    'terbang',
#    'segala',
#    'untuk',
#    'menantang',
#    'penentang',
#    'penetapan',
#    'ibu',
#    'kota',
#    'negara',
#    'disana',
#    'siapa',
#    'dan',
#    'dari',
#    'kelompok',
#    'mana'],
#   'polarity_score': -31,
#   'polarity': 'negative',
#   'positive_words': [('tempo', 1), ('sampai', 2), ('ada', 4), ('siapa', 1)],
#   'negative_words': [('yang', -5),
#    ('tempo', -4),
#    ('sampai', -4),
#    ('ada', -3),
#    ('yang', -5),
#    ('pamer', -3),
#    ('menantang', -4),
#    ('kota', -1),
#    ('siapa', -2),
#    ('dari', -3),
#    ('kelompok', -5)]},
#  {'text': 'Tunda IKN utk biaya menjalankan kontitusi',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Tunda IKN utk biaya menjalankan kontitusi',
#   'text_cleaning': 'tunda ikn utk biaya menjalankan kontitusi',
#   'text_normalisasi': 'tunda ibu kota negara untuk biaya menjalankan konstitusi',
#   'tweet_tokens': ['tunda',
#    'ibu',
#    'kota',
#    'negara',
#    'untuk',
#    'biaya',
#    'menjalankan',
#    'konstitusi'],
#   'polarity_score': -1,
#   'polarity': 'negative',
#   'positive_words': [],
#   'negative_words': [('kota', -1)]},
#  {'text': 'Biaekan saja minyak goreng mahal, daging sapi Dikuasai kartel, daging ayam mahal....kan bangun IKN tidak butuh yang begituan.....',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Biaekan saja minyak goreng mahal, daging sapi Dikuasai kartel, daging ayam mahal....kan bangun IKN tidak butuh yang begituan.....',
#   'text_cleaning': 'biaekan saja minyak goreng mahal daging sapi dikuasai kartel daging ayam mahalkan bangun ikn tidak butuh yang begituan',
#   'text_normalisasi': 'biarkan saja minyak goreng mahal daging sapi dikuasai kartel daging ayam mahalkan bangun ibu kota negara tidak butuh yang begituan',
#   'tweet_tokens': ['biarkan',
#    'saja',
#    'minyak',
#    'goreng',
#    'mahal',
#    'daging',
#    'sapi',
#    'dikuasai',
#    'kartel',
#    'daging',
#    'ayam',
#    'mahalkan',
#    'bangun',
#    'ibu',
#    'kota',
#    'negara',
#    'tidak',
#    'butuh',
#    'yang',
#    'begituan'],
#   'polarity_score': -24,
#   'polarity': 'negative',
#   'positive_words': [('biarkan', 1), ('goreng', 1), ('mahal', 1)],
#   'negative_words': [('biarkan', -3),
#    ('saja', -3),
#    ('goreng', -2),
#    ('sapi', -3),
#    ('kota', -1),
#    ('tidak', -5),
#    ('butuh', -5),
#    ('yang', -5)]},
#  {'text': 'Prediksi saya IKN akan buat musibah banjir bandang dikalimantan.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Prediksi saya IKN akan buat musibah banjir bandang dikalimantan.',
#   'text_cleaning': 'prediksi saya ikn akan buat musibah banjir bandang dikalimantan',
#   'text_normalisasi': 'prediksi saya ibu kota negara akan buat musibah banjir bandang dikalimantan',
#   'tweet_tokens': ['prediksi',
#    'saya',
#    'ibu',
#    'kota',
#    'negara',
#    'akan',
#    'buat',
#    'musibah',
#    'banjir',
#    'bandang',
#    'dikalimantan'],
#   'polarity_score': -10,
#   'polarity': 'negative',
#   'positive_words': [('prediksi', 3), ('buat', 1), ('banjir', 4)],
#   'negative_words': [('prediksi', -1),
#    ('saya', -3),
#    ('kota', -1),
#    ('musibah', -5),
#    ('banjir', -4),
#    ('bandang', -4)]},
#  {'text': 'Hasil kemah di IKN ya?? Tega benar mereka sama rakyat ya??? Big data plus bohong big kuasa big rakus...buat rakyat big susah mesti big sabar...bug sabar biar gak du cap radikal...terimakasih karena dzikir yg membersamai kami maka sabar masih didada.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Hasil kemah di IKN ya?? Tega benar mereka sama rakyat ya??? Big data plus bohong big kuasa big rakus...buat rakyat big susah mesti big sabar...bug sabar biar gak du cap radikal...terimakasih karena dzikir yg membersamai kami maka sabar masih didada.',
#   'text_cleaning': 'hasil kemah di ikn ya tega benar mereka sama rakyat ya big data plus bohong big kuasa big rakusbuat rakyat big susah mesti big sabarbug sabar biar gak du cap radikalterimakasih karena dzikir yg membersamai kami maka sabar masih didada',
#   'text_normalisasi': 'hasil kemah di ibu kota negara iya tega benar mereka sama rakyat iya besar data plus bohong besar kuasa besar rakusbuat rakyat besar susah mesti besar sabarbug sabar biar tidak du cap radikalterimakasih karena dzikir yang membersamai kami maka sabar masih di dada',
#   'tweet_tokens': ['hasil',
#    'kemah',
#    'di',
#    'ibu',
#    'kota',
#    'negara',
#    'iya',
#    'tega',
#    'benar',
#    'mereka',
#    'sama',
#    'rakyat',
#    'iya',
#    'besar',
#    'data',
#    'plus',
#    'bohong',
#    'besar',
#    'kuasa',
#    'besar',
#    'rakusbuat',
#    'rakyat',
#    'besar',
#    'susah',
#    'mesti',
#    'besar',
#    'sabarbug',
#    'sabar',
#    'biar',
#    'tidak',
#    'du',
#    'cap',
#    'radikalterimakasih',
#    'karena',
#    'dzikir',
#    'yang',
#    'membersamai',
#    'kami',
#    'maka',
#    'sabar',
#    'masih',
#    'di',
#    'dada'],
#   'polarity_score': -6,
#   'polarity': 'negative',
#   'positive_words': [('hasil', 3),
#    ('benar', 2),
#    ('sama', 3),
#    ('besar', 4),
#    ('plus', 2),
#    ('besar', 4),
#    ('kuasa', 3),
#    ('besar', 4),
#    ('besar', 4),
#    ('besar', 4),
#    ('sabar', 5),
#    ('biar', 1),
#    ('sabar', 5)],
#   'negative_words': [('kota', -1),
#    ('tega', -5),
#    ('benar', -4),
#    ('besar', -2),
#    ('data', -3),
#    ('bohong', -5),
#    ('besar', -2),
#    ('besar', -2),
#    ('besar', -2),
#    ('susah', -3),
#    ('mesti', -3),
#    ('besar', -2),
#    ('biar', -3),
#    ('tidak', -5),
#    ('karena', -3),
#    ('yang', -5)]},
#  {'text': 'Jadi gini, IKN itu bukan proyek abal2, butuh dana besar untuk mewujudkannya.\nYg jadi masalahnya cuma satu: Dananya Kagak Ada.\nMakanya yang bisa dilalukan baru sebatas seremoni pamer kendi.\n\nBadingkan Saudi yg punya duit, bangun apapun mana pernah pake pamer kendi?.\nTau2 Jadi.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Jadi gini, IKN itu bukan proyek abal2, butuh dana besar untuk mewujudkannya.\nYg jadi masalahnya cuma satu: Dananya Kagak Ada.\nMakanya yang bisa dilalukan baru sebatas seremoni pamer kendi.\n\nBadingkan Saudi yg punya duit, bangun apapun mana pernah pake pamer kendi?.\nTau2 Jadi.',
#   'text_cleaning': 'jadi gini ikn itu bukan proyek abal butuh dana besar untuk mewujudkannya yg jadi masalahnya cuma satu dananya kagak ada makanya yang bisa dilalukan baru sebatas seremoni pamer kendi badingkan saudi yg punya duit bangun apapun mana pernah pake pamer kendi tau jadi',
#   'text_normalisasi': 'jadi gini ibu kota negara itu bukan proyek abal butuh dana besar untuk mewujudkannya yang jadi masalahnya cuma satu dananya tidak ada makanya yang bisa dilewatkan baru sebatas seremoni pamer kendi badingkan saudi yang punya duit bangun apa pun mana pernah pakai pamer kendi tahu jadi',
#   'tweet_tokens': ['jadi',
#    'gini',
#    'ibu',
#    'kota',
#    'negara',
#    'itu',
#    'bukan',
#    'proyek',
#    'abal',
#    'butuh',
#    'dana',
#    'besar',
#    'untuk',
#    'mewujudkannya',
#    'yang',
#    'jadi',
#    'masalahnya',
#    'cuma',
#    'satu',
#    'dananya',
#    'tidak',
#    'ada',
#    'makanya',
#    'yang',
#    'bisa',
#    'dilewatkan',
#    'baru',
#    'sebatas',
#    'seremoni',
#    'pamer',
#    'kendi',
#    'badingkan',
#    'saudi',
#    'yang',
#    'punya',
#    'duit',
#    'bangun',
#    'apa',
#    'pun',
#    'mana',
#    'pernah',
#    'pakai',
#    'pamer',
#    'kendi',
#    'tahu',
#    'jadi'],
#   'polarity_score': -37,
#   'polarity': 'negative',
#   'positive_words': [('jadi', 1),
#    ('dana', 4),
#    ('besar', 4),
#    ('jadi', 1),
#    ('satu', 3),
#    ('ada', 4),
#    ('punya', 3),
#    ('tahu', 4),
#    ('jadi', 1)],
#   'negative_words': [('jadi', -2),
#    ('kota', -1),
#    ('itu', -2),
#    ('bukan', -3),
#    ('butuh', -5),
#    ('besar', -2),
#    ('yang', -5),
#    ('jadi', -2),
#    ('cuma', -3),
#    ('satu', -1),
#    ('tidak', -5),
#    ('ada', -3),
#    ('yang', -5),
#    ('pamer', -3),
#    ('yang', -5),
#    ('apa', -3),
#    ('pun', -3),
#    ('pamer', -3),
#    ('tahu', -4),
#    ('jadi', -2)]},
#  {'text': 'Apa tidak diajak rembugan?\nTidak dilibatkan dalam proyek IKN?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Apa tidak diajak rembugan?\nTidak dilibatkan dalam proyek IKN?',
#   'text_cleaning': 'apa tidak diajak rembugan tidak dilibatkan dalam proyek ikn',
#   'text_normalisasi': 'apa tidak diajak rembukan tidak dilibatkan dalam proyek ibu kota negara',
#   'tweet_tokens': ['apa',
#    'tidak',
#    'diajak',
#    'rembukan',
#    'tidak',
#    'dilibatkan',
#    'dalam',
#    'proyek',
#    'ibu',
#    'kota',
#    'negara'],
#   'polarity_score': -7,
#   'polarity': 'negative',
#   'positive_words': [('diajak', 1), ('rembukan', 3), ('dalam', 3)],
#   'negative_words': [('apa', -3), ('tidak', -5), ('tidak', -5), ('kota', -1)]},
#  {'text': 'IKN singkatan opo seh? Ibukota Karbitan?',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'IKN singkatan opo seh? Ibukota Karbitan?',
#   'text_cleaning': 'ikn singkatan opo seh ibukota karbitan',
#   'text_normalisasi': 'ibu kota negara singkatan opo seh ibu kota karbitan',
#   'tweet_tokens': ['ibu',
#    'kota',
#    'negara',
#    'singkatan',
#    'opo',
#    'seh',
#    'ibu',
#    'kota',
#    'karbitan'],
#   'polarity_score': -2,
#   'polarity': 'negative',
#   'positive_words': [],
#   'negative_words': [('kota', -1), ('kota', -1)]},
#  {'text': 'Padahal udah dikasih tau dari dulu, pembangunan IKN itu belum perlu karena masih banyak kebutuhan negara yg belum tercukupi.\nEh... Malah ngeyel. Giliran hutang membengkak, investor pada gak mau nanem dana di proyek... Pake alesan ada makelar lah, tnh udh di kavlinglah. RUWET',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Padahal udah dikasih tau dari dulu, pembangunan IKN itu belum perlu karena masih banyak kebutuhan negara yg belum tercukupi.\nEh... Malah ngeyel. Giliran hutang membengkak, investor pada gak mau nanem dana di proyek... Pake alesan ada makelar lah, tnh udh di kavlinglah. RUWET',
#   'text_cleaning': 'padahal udah dikasih tau dari dulu pembangunan ikn itu belum perlu karena masih banyak kebutuhan negara yg belum tercukupi eh malah ngeyel giliran hutang membengkak investor pada gak mau nanem dana di proyek pake alesan ada makelar lah tnh udh di kavlinglah ruwet',
#   'text_normalisasi': 'padahal sudah dikasih tahu dari dulu pembangunan ibu kota negara itu belum perlu karena masih banyak kebutuhan negara yang belum tercukupi eh bahkan ngeyel giliran hutang membengkak investor pada tidak mau menanam dana di proyek pakai alesan ada makelar lah tanah sudah di kavlinglah ruwet',
#   'tweet_tokens': ['padahal',
#    'sudah',
#    'dikasih',
#    'tahu',
#    'dari',
#    'dulu',
#    'pembangunan',
#    'ibu',
#    'kota',
#    'negara',
#    'itu',
#    'belum',
#    'perlu',
#    'karena',
#    'masih',
#    'banyak',
#    'kebutuhan',
#    'negara',
#    'yang',
#    'belum',
#    'tercukupi',
#    'eh',
#    'bahkan',
#    'ngeyel',
#    'giliran',
#    'hutang',
#    'membengkak',
#    'investor',
#    'pada',
#    'tidak',
#    'mau',
#    'menanam',
#    'dana',
#    'di',
#    'proyek',
#    'pakai',
#    'alesan',
#    'ada',
#    'makelar',
#    'lah',
#    'tanah',
#    'sudah',
#    'di',
#    'kavlinglah',
#    'ruwet'],
#   'polarity_score': -12,
#   'polarity': 'negative',
#   'positive_words': [('sudah', 3),
#    ('dikasih', 2),
#    ('tahu', 4),
#    ('perlu', 2),
#    ('banyak', 3),
#    ('kebutuhan', 4),
#    ('giliran', 3),
#    ('mau', 5),
#    ('dana', 4),
#    ('ada', 4),
#    ('sudah', 3)],
#   'negative_words': [('sudah', -2),
#    ('tahu', -4),
#    ('dari', -3),
#    ('kota', -1),
#    ('itu', -2),
#    ('karena', -3),
#    ('banyak', -3),
#    ('yang', -5),
#    ('hutang', -5),
#    ('pada', -3),
#    ('tidak', -5),
#    ('mau', -1),
#    ('ada', -3),
#    ('makelar', -3),
#    ('sudah', -2),
#    ('ruwet', -4)]},
#  {'text': 'Maksudya bisa jadi SOP baru utk mensejahterakan oligarki .. bisa jadi apalagi momentnya pas, mau puasa dan IKN butuh banyak biaya ... ah nggak percuma nyepi di titik nol...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Maksudya bisa jadi SOP baru utk mensejahterakan oligarki .. bisa jadi apalagi momentnya pas, mau puasa dan IKN butuh banyak biaya ... ah nggak percuma nyepi di titik nol...',
#   'text_cleaning': 'maksudya bisa jadi sop baru utk mensejahterakan oligarki bisa jadi apalagi momentnya pas mau puasa dan ikn butuh banyak biaya ah nggak percuma nyepi di titik nol',
#   'text_normalisasi': 'maksudnya bisa jadi sop baru untuk mensejahterakan oligarki bisa jadi apalagi momentnya pas mau puasa dan ibu kota negara butuh banyak biaya ah tidak percuma nyepi di titik nol',
#   'tweet_tokens': ['maksudnya',
#    'bisa',
#    'jadi',
#    'sop',
#    'baru',
#    'untuk',
#    'mensejahterakan',
#    'oligarki',
#    'bisa',
#    'jadi',
#    'apalagi',
#    'momentnya',
#    'pas',
#    'mau',
#    'puasa',
#    'dan',
#    'ibu',
#    'kota',
#    'negara',
#    'butuh',
#    'banyak',
#    'biaya',
#    'ah',
#    'tidak',
#    'percuma',
#    'nyepi',
#    'di',
#    'titik',
#    'nol'],
#   'polarity_score': -15,
#   'polarity': 'negative',
#   'positive_words': [('jadi', 1),
#    ('jadi', 1),
#    ('pas', 3),
#    ('mau', 5),
#    ('banyak', 3),
#    ('percuma', 4)],
#   'negative_words': [('maksudnya', -1),
#    ('jadi', -2),
#    ('jadi', -2),
#    ('mau', -1),
#    ('puasa', -2),
#    ('kota', -1),
#    ('butuh', -5),
#    ('banyak', -3),
#    ('tidak', -5),
#    ('percuma', -4),
#    ('titik', -3),
#    ('nol', -3)]},
#  {'text': 'IKN IKN, urus tuh harga minyak goreng!',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'IKN IKN, urus tuh harga minyak goreng!',
#   'text_cleaning': 'ikn ikn urus tuh harga minyak goreng',
#   'text_normalisasi': 'ibu kota negara ibu kota negara urus tuh harga minyak goreng',
#   'tweet_tokens': ['ibu',
#    'kota',
#    'negara',
#    'ibu',
#    'kota',
#    'negara',
#    'urus',
#    'tuh',
#    'harga',
#    'minyak',
#    'goreng'],
#   'polarity_score': 0,
#   'polarity': 'neutral',
#   'positive_words': [('harga', 3), ('goreng', 1)],
#   'negative_words': [('kota', -1), ('kota', -1), ('goreng', -2)]},
#  {'text': 'Banjir lagi OTW ke IKN.,...via Balikpapan...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Banjir lagi OTW ke IKN.,...via Balikpapan...',
#   'text_cleaning': 'banjir lagi otw ke iknvia balikpapan',
#   'text_normalisasi': 'banjir lagi on the way, sedang di jalan ke iknvia balikpapan',
#   'tweet_tokens': ['banjir',
#    'lagi',
#    'on',
#    'the',
#    'way,',
#    'sedang',
#    'di',
#    'jalan',
#    'ke',
#    'iknvia',
#    'balikpapan'],
#   'polarity_score': -3,
#   'polarity': 'negative',
#   'positive_words': [('banjir', 4)],
#   'negative_words': [('banjir', -4), ('lagi', -3)]},
#  {'text': 'Yang paling ditakutkan dari mutasi ke IKN baru itu bukan pindah jauh dari keluarga, tapi temen2nya ikut pindah juga gak.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Yang paling ditakutkan dari mutasi ke IKN baru itu bukan pindah jauh dari keluarga, tapi temen2nya ikut pindah juga gak.',
#   'text_cleaning': 'yang paling ditakutkan dari mutasi ke ikn baru itu bukan pindah jauh dari keluarga tapi temennya ikut pindah juga gak',
#   'text_normalisasi': 'yang paling ditakutkan dari mutasi ke ibu kota negara baru itu bukan pindah jauh dari keluarga  tapi temannya ikut pindah juga tidak',
#   'tweet_tokens': ['yang',
#    'paling',
#    'ditakutkan',
#    'dari',
#    'mutasi',
#    'ke',
#    'ibu',
#    'kota',
#    'negara',
#    'baru',
#    'itu',
#    'bukan',
#    'pindah',
#    'jauh',
#    'dari',
#    'keluarga',
#    'tapi',
#    'temannya',
#    'ikut',
#    'pindah',
#    'juga',
#    'tidak'],
#   'polarity_score': -32,
#   'polarity': 'negative',
#   'positive_words': [('pindah', 1), ('keluarga', 4), ('pindah', 1)],
#   'negative_words': [('yang', -5),
#    ('dari', -3),
#    ('kota', -1),
#    ('itu', -2),
#    ('bukan', -3),
#    ('pindah', -3),
#    ('jauh', -4),
#    ('dari', -3),
#    ('keluarga', -3),
#    ('ikut', -3),
#    ('pindah', -3),
#    ('tidak', -5)]},
#  {'text': 'Dipaksakan bangun ikn dari hutang masalah distribusi migor , solar juga ngak bener ngak cari solusi utk rakyat',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Dipaksakan bangun ikn dari hutang masalah distribusi migor , solar juga ngak bener ngak cari solusi utk rakyat',
#   'text_cleaning': 'dipaksakan bangun ikn dari hutang masalah distribusi migor solar juga ngak bener ngak cari solusi utk rakyat',
#   'text_normalisasi': 'dipaksakan bangun ibu kota negara dari hutang masalah distribusi minyak goreng solar juga tidak benar tidak cari solusi untuk rakyat',
#   'tweet_tokens': ['dipaksakan',
#    'bangun',
#    'ibu',
#    'kota',
#    'negara',
#    'dari',
#    'hutang',
#    'masalah',
#    'distribusi',
#    'minyak',
#    'goreng',
#    'solar',
#    'juga',
#    'tidak',
#    'benar',
#    'tidak',
#    'cari',
#    'solusi',
#    'untuk',
#    'rakyat'],
#   'polarity_score': -23,
#   'polarity': 'negative',
#   'positive_words': [('distribusi', 3),
#    ('goreng', 1),
#    ('benar', 2),
#    ('solusi', 3)],
#   'negative_words': [('kota', -1),
#    ('dari', -3),
#    ('hutang', -5),
#    ('masalah', -4),
#    ('goreng', -2),
#    ('tidak', -5),
#    ('benar', -4),
#    ('tidak', -5),
#    ('cari', -3)]},
#  {'text': 'Prilaku bangsa kita cenderung lebih suka becanda ya, Segalah ritual kendi yg jd sorotan publik. fokus soroti dampak lingkungan, ekonomi, pertahanan dll knp jd kendi yg rame, jdinya suara dr istana malah jelasin soal kendi kan bkn IKN.\n#Gempa\n#jokowi3periode\n#Tangkap2AnakJokowi',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Prilaku bangsa kita cenderung lebih suka becanda ya, Segalah ritual kendi yg jd sorotan publik. fokus soroti dampak lingkungan, ekonomi, pertahanan dll knp jd kendi yg rame, jdinya suara dr istana malah jelasin soal kendi kan bkn IKN.\n#Gempa\n#jokowi3periode\n#Tangkap2Anak Jokowi',
#   'text_cleaning': 'prilaku bangsa kita cenderung lebih suka becanda ya segalah ritual kendi yg jd sorotan publik fokus soroti dampak lingkungan ekonomi pertahanan dll knp jd kendi yg rame jdinya suara dr istana malah jelasin soal kendi kan bkn ikn gempa jokowiperiode tangkapanak jokowi',
# ...
#   'text_normalisasi': 'mengumpulkan jin dayang  seluruh indonesia mau di jadikan satu pindah di kalimantan ibu kota negara ngk kuat denger suara adzan silahkan saja untuk penghuni istana dan pendukungnya sudah keblinger maka akan kehendak',
#   'tweet_tokens': ['mengumpulkan',
#    'jin',
#    'dayang',
#    'seluruh',
#    'indonesia',
#    'mau',
#    'di',
#    'jadikan',
#    'satu',
#    'pindah',
#    'di',
#    'kalimantan',
#    'ibu',
#    'kota',
#    'negara',
#    'ngk',
#    'kuat',
#    'denger',
#    'suara',
#    'adzan',
#    'silahkan',
#    'saja',
#    'untuk',
#    'penghuni',
#    'istana',
#    'dan',
#    'pendukungnya',
#    'sudah',
#    'keblinger',
#    'maka',
#    'akan',
#    'kehendak'],
#   'polarity_score': 7,
#   'polarity': 'positive',
#   'positive_words': [('mengumpulkan', 3),
#    ('mau', 5),
#    ('satu', 3),
#    ('pindah', 1),
#    ('kuat', 2),
#    ('suara', 2),
#    ('adzan', 3),
#    ('silahkan', 3),
#    ('penghuni', 3),
#    ('sudah', 3)],
#   'negative_words': [('jin', -3),
#    ('mau', -1),
#    ('satu', -1),
#    ('pindah', -3),
#    ('kota', -1),
#    ('kuat', -3),
#    ('denger', -3),
#    ('suara', -1),
#    ('saja', -3),
#    ('sudah', -2)]},
#  {'text': 'Baguslah..mending semua investor buat IKN pikir ulang lagi dah..',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Baguslah..mending semua investor buat IKN pikir ulang lagi dah..',
#   'text_cleaning': 'baguslahmending semua investor buat ikn pikir ulang lagi dah',
#   'text_normalisasi': 'baguslahmending semua investor buat ibu kota negara pikir ulang lagi deh',
#   'tweet_tokens': ['baguslahmending',
#    'semua',
#    'investor',
#    'buat',
#    'ibu',
#    'kota',
#    'negara',
#    'pikir',
#    'ulang',
#    'lagi',
#    'deh'],
#   'polarity_score': -7,
#   'polarity': 'negative',
#   'positive_words': [('buat', 1), ('pikir', 1)],
#   'negative_words': [('semua', -3),
#    ('kota', -1),
#    ('pikir', -2),
#    ('lagi', -3)]},
#  {'text': 'Sabar mas kalau emank IKN benar2 jd itu jg merupakan titik balik perpindahan kepemipinan nasional bkn lg org jawa karena tuahnya sdh pindah haluan ke kalimantan...sebrang lautan..',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Sabar mas kalau emank IKN benar2 jd itu jg merupakan titik balik perpindahan kepemipinan nasional bkn lg org jawa karena tuahnya sdh pindah haluan ke kalimantan...sebrang lautan..',
#   'text_cleaning': 'sabar mas kalau emank ikn benar jd itu jg merupakan titik balik perpindahan kepemipinan nasional bkn lg org jawa karena tuahnya sdh pindah haluan ke kalimantansebrang lautan',
#   'text_normalisasi': 'sabar mas kalau emank ibu kota negara benar jadi itu juga merupakan titik balik perpindahan kepemipinan nasional bukan lagi orang jawa karena tuahnya sudah pindah haluan ke kalimantansebrang lautan',
#   'tweet_tokens': ['sabar',
#    'mas',
#    'kalau',
#    'emank',
#    'ibu',
#    'kota',
#    'negara',
#    'benar',
#    'jadi',
#    'itu',
#    'juga',
#    'merupakan',
#    'titik',
#    'balik',
#    'perpindahan',
#    'kepemipinan',
#    'nasional',
#    'bukan',
#    'lagi',
#    'orang',
#    'jawa',
#    'karena',
#    'tuahnya',
#    'sudah',
#    'pindah',
#    'haluan',
#    'ke',
#    'kalimantansebrang',
#    'lautan'],
#   'polarity_score': -18,
#   'polarity': 'negative',
#   'positive_words': [('sabar', 5),
#    ('benar', 2),
#    ('jadi', 1),
#    ('sudah', 3),
#    ('pindah', 1)],
#   'negative_words': [('kalau', -1),
#    ('kota', -1),
#    ('benar', -4),
#    ('jadi', -2),
#    ('itu', -2),
#    ('titik', -3),
#    ('balik', -3),
#    ('bukan', -3),
#    ('lagi', -3),
#    ('karena', -3),
#    ('sudah', -2),
#    ('pindah', -3)]},
#  {'text': 'Oia, satu lagi...soal logo. Kenapa logo nya harus kaligrafi dalam bentuk gunungan wayang? Apakah mau "menusantarakan Islam" atau menunjukkan bahwa Indonesia adalah Jawa? Bukan kah IKN pun (katanya) dibentuk utk menghapus Jawa Sentris? Tapi logo halal pake gunungan wayang Jawa.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Oia, satu lagi...soal logo. Kenapa logo nya harus kaligrafi dalam bentuk gunungan wayang? Apakah mau "menusantarakan Islam" atau menunjukkan bahwa Indonesia adalah Jawa? Bukan kah IKN pun (katanya) dibentuk utk menghapus Jawa Sentris? Tapi logo halal pake gunungan wayang Jawa.',
#   'text_cleaning': 'oia satu lagisoal logo kenapa logo nya harus kaligrafi dalam bentuk gunungan wayang apakah mau menusantarakan islam atau menunjukkan bahwa indonesia adalah jawa bukan kah ikn pun katanya dibentuk utk menghapus jawa sentris tapi logo halal pake gunungan wayang jawa',
#   'text_normalisasi': 'oia satu lagisoal logo kenapa logo nya harus kaligrafi dalam bentuk gunungan wayang apakah mau menusantarakan islam atau menunjukkan bahwa indonesia adalah jawa bukan kah ibu kota negara pun katanya dibentuk untuk menghapus jawa sentris tapi logo halal pakai gunungan wayang jawa',
#   'tweet_tokens': ['oia',
#    'satu',
#    'lagisoal',
#    'logo',
#    'kenapa',
#    'logo',
#    'nya',
#    'harus',
#    'kaligrafi',
#    'dalam',
#    'bentuk',
#    'gunungan',
#    'wayang',
#    'apakah',
#    'mau',
#    'menusantarakan',
#    'islam',
#    'atau',
#    'menunjukkan',
#    'bahwa',
#    'indonesia',
#    'adalah',
#    'jawa',
#    'bukan',
#    'kah',
#    'ibu',
#    'kota',
#    'negara',
#    'pun',
#    'katanya',
#    'dibentuk',
#    'untuk',
#    'menghapus',
#    'jawa',
#    'sentris',
#    'tapi',
#    'logo',
#    'halal',
#    'pakai',
#    'gunungan',
#    'wayang',
#    'jawa'],
#   'polarity_score': -3,
#   'polarity': 'negative',
#   'positive_words': [('satu', 3),
#    ('dalam', 3),
#    ('bentuk', 4),
#    ('mau', 5),
#    ('islam', 4)],
#   'negative_words': [('satu', -1),
#    ('harus', -5),
#    ('mau', -1),
#    ('menunjukkan', -3),
#    ('bukan', -3),
#    ('kota', -1),
#    ('pun', -3),
#    ('katanya', -1),
#    ('menghapus', -4)]},
#  {'text': 'Semoga klo IKN gagal..masyarakat sadar TDK semua budaya itu membawa kebaikan..jika mereka bilang budaya Arab dibawa karena kepentingan khilafah maka budaya Nusantara bisa dibawa buat kepentingan rezim..Nah kan',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Semoga klo IKN gagal..masyarakat sadar TDK semua budaya itu membawa kebaikan..jika mereka bilang budaya Arab dibawa karena kepentingan khilafah maka budaya Nusantara bisa dibawa buat kepentingan rezim..Nah kan',
#   'text_cleaning': 'semoga klo ikn gagalmasyarakat sadar tdk semua budaya itu membawa kebaikanjika mereka bilang budaya arab dibawa karena kepentingan khilafah maka budaya nusantara bisa dibawa buat kepentingan rezimnah kan',
#   'text_normalisasi': 'semoga kalau ibu kota negara gagalmasyarakat sadar tidak semua budaya itu membawa kebaikanjika mereka bilang budaya arab dibawa karena kepentingan khilafah maka budaya nusantara bisa dibawa buat kepentingan rezimnah kan',
#   'tweet_tokens': ['semoga',
#    'kalau',
#    'ibu',
#    'kota',
#    'negara',
#    'gagalmasyarakat',
#    'sadar',
#    'tidak',
#    'semua',
#    'budaya',
#    'itu',
#    'membawa',
#    'kebaikanjika',
#    'mereka',
#    'bilang',
#    'budaya',
#    'arab',
#    'dibawa',
#    'karena',
#    'kepentingan',
#    'khilafah',
#    'maka',
#    'budaya',
#    'nusantara',
#    'bisa',
#    'dibawa',
#    'buat',
#    'kepentingan',
#    'rezimnah',
#    'kan'],
#   'polarity_score': -3,
#   'polarity': 'negative',
#   'positive_words': [('sadar', 2),
#    ('kepentingan', 5),
#    ('buat', 1),
#    ('kepentingan', 5)],
#   'negative_words': [('kalau', -1),
#    ('kota', -1),
#    ('sadar', -1),
#    ('tidak', -5),
#    ('semua', -3),
#    ('itu', -2),
#    ('karena', -3)]},
#  {'text': 'Gerombolan mrk sangat alegi dgn tulisan Arab, hampir diseluruh dunia memakai tulisan spt itu krn memang kata halal itu dari bahasa Arab. Tapi lbp ujuk² pergi ngemis ke Arab Saudi cari utangan utk membangun IKN, gak MALU ya!!!',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Gerombolan mrk sangat alegi dgn tulisan Arab, hampir diseluruh dunia memakai tulisan spt itu krn memang kata halal itu dari bahasa Arab. Tapi lbp ujuk² pergi ngemis ke Arab Saudi cari utangan utk membangun IKN, gak MALU ya!!!',
#   'text_cleaning': 'gerombolan mrk sangat alegi dgn tulisan arab hampir diseluruh dunia memakai tulisan spt itu krn memang kata halal itu dari bahasa arab tapi lbp ujuk pergi ngemis ke arab saudi cari utangan utk membangun ikn gak malu ya',
#   'text_normalisasi': 'gerombolan mrk sangat alegi dengan tulisan arab hampir di seluruh dunia memakai tulisan seperti itu karena memang kata halal itu dari bahasa arab tapi luhut binsar panjaitan ujuk pergi ngemis ke arab saudi cari utangan untuk membangun ibu kota negara tidak malu iya',
#   'tweet_tokens': ['gerombolan',
#    'mrk',
#    'sangat',
#    'alegi',
#    'dengan',
#    'tulisan',
#    'arab',
#    'hampir',
#    'di',
#    'seluruh',
#    'dunia',
#    'memakai',
#    'tulisan',
#    'seperti',
#    'itu',
#    'karena',
#    'memang',
#    'kata',
#    'halal',
#    'itu',
#    'dari',
#    'bahasa',
#    'arab',
#    'tapi',
#    'luhut',
#    'binsar',
#    'panjaitan',
#    'ujuk',
#    'pergi',
#    'ngemis',
#    'ke',
#    'arab',
#    'saudi',
#    'cari',
#    'utangan',
#    'untuk',
#    'membangun',
#    'ibu',
#    'kota',
#    'negara',
#    'tidak',
#    'malu',
#    'iya'],
#   'polarity_score': -34,
#   'polarity': 'negative',
#   'positive_words': [('sangat', 3),
#    ('dunia', 1),
#    ('memang', 4),
#    ('pergi', 1),
#    ('malu', 2)],
#   'negative_words': [('gerombolan', -4),
#    ('sangat', -5),
#    ('dunia', -2),
#    ('seperti', -1),
#    ('itu', -2),
#    ('karena', -3),
#    ('memang', -2),
#    ('kata', -1),
#    ('itu', -2),
#    ('dari', -3),
#    ('bahasa', -4),
#    ('pergi', -3),
#    ('cari', -3),
#    ('kota', -1),
#    ('tidak', -5),
#    ('malu', -4)]},
#  {'text': 'Pemerintah lagi sibuk berkemah dan gerilya buat cari investor asing buat IKN...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Pemerintah lagi sibuk berkemah dan gerilya buat cari investor asing buat IKN...',
#   'text_cleaning': 'pemerintah lagi sibuk berkemah dan gerilya buat cari investor asing buat ikn',
#   'text_normalisasi': 'pemerintah lagi sibuk berkemah dan gerilya buat cari investor asing buat ibu kota negara',
#   'tweet_tokens': ['pemerintah',
#    'lagi',
#    'sibuk',
#    'berkemah',
#    'dan',
#    'gerilya',
#    'buat',
#    'cari',
#    'investor',
#    'asing',
#    'buat',
#    'ibu',
#    'kota',
#    'negara'],
#   'polarity_score': -4,
#   'polarity': 'negative',
#   'positive_words': [('sibuk', 4), ('buat', 1), ('buat', 1)],
#   'negative_words': [('lagi', -3), ('sibuk', -3), ('cari', -3), ('kota', -1)]},
#  {'text': 'Mungkin perlu ditambahkan janji ke 5.Presiden sepertinya pernah janji bahwa pembiayaan IKN tidak menggunakan APBN.',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Mungkin perlu ditambahkan janji ke 5.Presiden sepertinya pernah janji bahwa pembiayaan IKN tidak menggunakan APBN.',
#   'text_cleaning': 'mungkin perlu ditambahkan janji ke presiden sepertinya pernah janji bahwa pembiayaan ikn tidak menggunakan apbn',
#   'text_normalisasi': 'mungkin perlu ditambahkan janji ke presiden sepertinya pernah janji bahwa pembiayaan ibu kota negara tidak menggunakan anggaran pendapatan dan belanja negara',
#   'tweet_tokens': ['mungkin',
#    'perlu',
#    'ditambahkan',
#    'janji',
#    'ke',
#    'presiden',
#    'sepertinya',
#    'pernah',
#    'janji',
#    'bahwa',
#    'pembiayaan',
#    'ibu',
#    'kota',
#    'negara',
#    'tidak',
#    'menggunakan',
#    'anggaran',
#    'pendapatan',
#    'dan',
#    'belanja',
#    'negara'],
#   'polarity_score': -6,
#   'polarity': 'negative',
#   'positive_words': [('perlu', 2),
#    ('presiden', 3),
#    ('pendapatan', 2),
#    ('belanja', 2)],
#   'negative_words': [('mungkin', -1),
#    ('sepertinya', -2),
#    ('kota', -1),
#    ('tidak', -5),
#    ('pendapatan', -3),
#    ('belanja', -3)]},
#  {'text': 'ikn batal mas ... lercaya saja sama mayoritas rakyat tidak setuju ikn lindah. tanda2nya mulai bank investor mundur...',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'ikn batal mas ... lercaya saja sama mayoritas rakyat tidak setuju ikn lindah. tanda2nya mulai bank investor mundur...',
#   'text_cleaning': 'ikn batal mas lercaya saja sama mayoritas rakyat tidak setuju ikn lindah tandanya mulai bank investor mundur',
#   'text_normalisasi': 'ibu kota negara batal mas percaya saja sama mayoritas rakyat tidak setuju ibu kota negara lidah tandanya mulai bank investor mundur',
#   'tweet_tokens': ['ibu',
#    'kota',
#    'negara',
#    'batal',
#    'mas',
#    'percaya',
#    'saja',
#    'sama',
#    'mayoritas',
#    'rakyat',
#    'tidak',
#    'setuju',
#    'ibu',
#    'kota',
#    'negara',
#    'lidah',
#    'tandanya',
#    'mulai',
#    'bank',
#    'investor',
#    'mundur'],
#   'polarity_score': -10,
#   'polarity': 'negative',
#   'positive_words': [('percaya', 2), ('sama', 3), ('setuju', 4), ('mulai', 1)],
#   'negative_words': [('kota', -1),
#    ('batal', -5),
#    ('saja', -3),
#    ('tidak', -5),
#    ('setuju', -3),
#    ('kota', -1),
#    ('tandanya', -2)]},
#  {'text': 'Wong masa jabatan udah mau habis, penerus nya belum tentu mau melanjutkan,rugi bandar lah invest gede belum tentu balik modal... Karena itulah pemilu ditunda atau 3 periode buat mengamankan ikn dan kebijakan laen nya,paling tidak kabinet bersih-bersih',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Wong masa jabatan udah mau habis, penerus nya belum tentu mau melanjutkan,rugi bandar lah invest gede belum tentu balik modal... Karena itulah pemilu ditunda atau 3 periode buat mengamankan ikn dan kebijakan laen nya,paling tidak kabinet bersih-bersih',
#   'text_cleaning': 'wong masa jabatan udah mau habis penerus nya belum tentu mau melanjutkanrugi bandar lah invest gede belum tentu balik modal karena itulah pemilu ditunda atau  periode buat mengamankan ikn dan kebijakan laen nyapaling tidak kabinet bersih-bersih',
#   'text_normalisasi': 'wong masa jabatan sudah mau habis penerus nya belum tentu mau melanjutkanrugi bandar lah invest besar belum tentu balik modal karena itulah pemilu ditunda atau  periode buat mengamankan ibu kota negara dan kebijakan lain nyapaling tidak kabinet bersih-bersih',
#   'tweet_tokens': ['wong',
#    'masa',
#    'jabatan',
#    'sudah',
#    'mau',
#    'habis',
#    'penerus',
#    'nya',
#    'belum',
#    'tentu',
#    'mau',
#    'melanjutkanrugi',
#    'bandar',
#    'lah',
#    'invest',
#    'besar',
#    'belum',
#    'tentu',
#    'balik',
#    'modal',
#    'karena',
#    'itulah',
#    'pemilu',
#    'ditunda',
#    'atau',
#    'periode',
#    'buat',
#    'mengamankan',
#    'ibu',
#    'kota',
#    'negara',
#    'dan',
#    'kebijakan',
#    'lain',
#    'nyapaling',
#    'tidak',
#    'kabinet',
#    'bersih-bersih'],
#   'polarity_score': -15,
#   'polarity': 'negative',
#   'positive_words': [('sudah', 3),
#    ('mau', 5),
#    ('habis', 3),
#    ('mau', 5),
#    ('besar', 4),
#    ('modal', 2),
#    ('buat', 1),
#    ('kebijakan', 3)],
#   'negative_words': [('sudah', -2),
#    ('mau', -1),
#    ('habis', -3),
#    ('tentu', -3),
#    ('mau', -1),
#    ('bandar', -4),
#    ('besar', -2),
#    ('tentu', -3),
#    ('balik', -3),
#    ('modal', -3),
#    ('karena', -3),
#    ('kota', -1),
#    ('lain', -4),
#    ('tidak', -5),
#    ('kabinet', -3)]},
#  {'text': 'Komisi Pemberantasan Korupsi (KPK) juga sudah mengingatkan akan potensi hal itu. #LaNyalla #KataLaNyalla #dpdri #JokowiHarusDiturunkan #IKN',
#   'label': 'negative',
#   'pisah_hashtag&kata': 'Komisi Pemberantasan Korupsi (KPK) juga sudah mengingatkan akan potensi hal itu. #La Nyalla #Kata La Nyalla #dpdri #Jokowi Harus Diturunkan #IKN',
#   'text_cleaning': 'komisi pemberantasan korupsi kpk juga sudah mengingatkan akan potensi hal itu la nyalla kata la nyalla dpdri jokowi harus diturunkan ikn',
#   'text_normalisasi': 'komisi pemberantasan korupsi kpkjuga sudah mengingatkan akan potensihal itu lah hidup kata lah hidup dpd ri jokowi  harus diturunkan ibu kota negara',
#   'tweet_tokens': ['komisi',
#    'pemberantasan',
#    'korupsi',
#    'kpkjuga',
#    'sudah',
#    'mengingatkan',
#    'akan',
#    'potensihal',
#    'itu',
#    'lah',
#    'hidup',
#    'kata',
#    'lah',
#    'hidup',
#    'dpd',
#    'ri',
#    'jokowi',
#    'harus',
#    'diturunkan',
#    'ibu',
#    'kota',
#    'negara'],
#   'polarity_score': -10,
#   'polarity': 'negative',
#   'positive_words': [('komisi', 3),
#    ('sudah', 3),
#    ('mengingatkan', 3),
#    ('hidup', 2),
#    ('hidup', 2)],
#   'negative_words': [('korupsi', -4),
#    ('sudah', -2),
#    ('itu', -2),
#    ('hidup', -4),
#    ('kata', -1),
#    ('hidup', -4),
#    ('harus', -5),
#    ('kota', -1)]},
#  ...]

# %%
write_csv('no_library/Hasil_tweets_data.csv', data)

# %%
# Print polarity counts
polarity_counts = defaultdict(int)
for row in data:
    polarity_counts[row['polarity']] += 1

print(polarity_counts)
# Out:
# defaultdict(<class 'int'>, {'negative': 10633, 'neutral': 402, 'positive': 1485})

# %%
# Visualization (without matplotlib)
def simple_pie_chart(counts, title):
    total = sum(counts.values())
    print(f"{title}\n")
    for label, count in counts.items():
        print(f"{label}: {count / total:.1%} ({count})")

simple_pie_chart(polarity_counts, 'Sentiment Polarity on Tweets Data')
# Out:
# Sentiment Polarity on Tweets Data
#
# negative: 84.9% (10633)
# neutral: 3.2% (402)
# positive: 11.9% (1485)

# %%
# Save positive and negative tweets
positive_tweets = [row for row in data if row['polarity'] == 'positive']
positive_tweets.sort(key=lambda x: x['polarity_score'], reverse=True)

# %%
negative_tweets = [row for row in data if row['polarity'] == 'negative']
negative_tweets.sort(key=lambda x: x['polarity_score'])

# %%
# Visualize word cloud (without wordcloud library)
from collections import Counter

def generate_word_cloud(words):
    word_counts = Counter(words)
    for word, count in word_counts.most_common(20):
        print(f"{word}: {count}")

all_words = [word for row in data for word in row['tweet_tokens']]
generate_word_cloud(all_words)

def words_with_sentiment(text):
    positive_words = []
    negative_words = []
    for word in text:
        if word in lexicon_positive:
            positive_words.append(word)
        if word in lexicon_negative:
            negative_words.append(word)
    return positive_words, negative_words

sentiment_words = [words_with_sentiment(row['tweet_tokens']) for row in data]
positive_words = [word for sublist in sentiment_words for word in sublist[0]]
negative_words = [word for sublist in sentiment_words for word in sublist[1]]
# Out:
# negara: 14264
# kota: 13950
# ibu: 13805
# yang: 5442
# tidak: 4587
# di: 4536
# dan: 3480
# ada: 2044
# ini: 1881
# itu: 1860
# saja: 1757
# jadi: 1722
# dari: 1698
# kalau: 1657
# ke: 1513
# sudah: 1502
# untuk: 1489
# rakyat: 1474
# dengan: 1396
# iya: 1282

# %%
print("Positive Words Word Cloud")
generate_word_cloud(positive_words)

print("Negative Words Word Cloud")
generate_word_cloud(negative_words)
# Out:
# Positive Words Word Cloud
# ada: 2044
# jadi: 1722
# sudah: 1502
# mau: 1275
# presiden: 928
# buat: 892
# goreng: 890
# sama: 811
# lebih: 780
# pindah: 671
# banyak: 668
# dalam: 496
# sampai: 433
# baik: 421
# tahu: 417
# bawa: 378
# para: 362
# punya: 358
# besar: 356
# dana: 350
# Negative Words Word Cloud
# kota: 13950
# yang: 5442
# tidak: 4587
# ada: 2044
# itu: 1860
# saja: 1757
# jadi: 1722
# dari: 1698
# kalau: 1657
# sudah: 1502
# mau: 1275
# apa: 1120
# lagi: 1075
# goreng: 890
# saya: 873
# karena: 842
# bukan: 708
# pindah: 671
# banyak: 668
# air: 617
